# %% [markdown]
# ## Chapter 4 – Exercise 3:  Sử dụng Mysql Connector để thực hiện các truy vấn dữ liệu trên nhiều bảng

# %% [markdown]
# #### Học viên thực hiện các yêu cầu sau và đối chiếu với kết quả cho trước:

# %%
from mysql.connector import connect

# %%
def run_sql(sql):
    cur = conn.cursor()
    cur.execute(sql)
    row = cur.fetchone()
    while row:
        print(row)
        row = cur.fetchone()    
    cur.close()

# %%
import glob 
mydir = "EX3/"
fnames = glob.glob(mydir+'*.sql')

# %%
conn = connect(host='localhost', port=3308, database='salesdb', user='root', password='')

# %%
for name in fnames:
    f = open(name, 'r', encoding="UTF-8")
    script = f.read()
    f.close()
    print('*'*70)
    print('file name:', name)
    print(script)
    print('*'*70)
    run_sql(script)
# Out:
# **********************************************************************
# file name: EX3\01.sql
# SELECT p.Id, p.ProductName, p.UnitPrice, s.CompanyName
# FROM products p JOIN suppliers s ON p.SupplierId=s.Id
# ORDER BY s.CompanyName;
# **********************************************************************
# (38, 'Côte de Blaye', Decimal('263.50'), 'Aux joyeux ecclésiastiques')
# (39, 'Chartreuse verte', Decimal('18.00'), 'Aux joyeux ecclésiastiques')
# (35, 'Steeleye Stout', Decimal('18.00'), 'Bigfoot Breweries')
# (67, 'Laughing Lumberjack Lager', Decimal('14.00'), 'Bigfoot Breweries')
# (34, 'Sasquatch Ale', Decimal('14.00'), 'Bigfoot Breweries')
# (11, 'Queso Cabrales', Decimal('21.00'), "Cooperativa de Quesos 'Las Cabras'")
# (12, 'Queso Manchego La Pastora', Decimal('38.00'), "Cooperativa de Quesos 'Las Cabras'")
# (58, 'Escargots de Bourgogne', Decimal('13.25'), 'Escargots Nouveaux')
# (3, 'Aniseed Syrup', Decimal('10.00'), 'Exotic Liquids')
# (1, 'Chai', Decimal('18.00'), 'Exotic Liquids')
# (2, 'Chang', Decimal('19.00'), 'Exotic Liquids')
# (62, 'Tarte au sucre', Decimal('49.30'), "Forêts d'érables")
# (61, "Sirop d'érable", Decimal('28.50'), "Forêts d'érables")
# (72, 'Mozzarella di Giovanni', Decimal('34.80'), 'Formaggi Fortini s.r.l.')
# (31, 'Gorgonzola Telino', Decimal('12.50'), 'Formaggi Fortini s.r.l.')
# (32, 'Mascarpone Fabioli', Decimal('32.00'), 'Formaggi Fortini s.r.l.')
# (52, 'Filo Mix', Decimal('7.00'), "G'day, Mate")
# (53, 'Perth Pasties', Decimal('32.80'), "G'day, Mate")
# (51, 'Manjimup Dried Apples', Decimal('53.00'), "G'day, Mate")
# (60, 'Camembert Pierrot', Decimal('34.00'), 'Gai pâturage')
# (59, 'Raclette Courdavault', Decimal('55.00'), 'Gai pâturage')
# (8, 'Northwoods Cranberry Sauce', Decimal('40.00'), "Grandma Kelly's Homestead")
# (6, "Grandma's Boysenberry Spread", Decimal('25.00'), "Grandma Kelly's Homestead")
# (7, "Uncle Bob's Organic Dried Pears", Decimal('30.00'), "Grandma Kelly's Homestead")
# (25, 'NuNuCa Nuß-Nougat-Creme', Decimal('14.00'), 'Heli Süßwaren GmbH & Co. KG')
# (26, 'Gumbär Gummibärchen', Decimal('31.23'), 'Heli Süßwaren GmbH & Co. KG')
# (27, 'Schoggi Schokolade', Decimal('43.90'), 'Heli Süßwaren GmbH & Co. KG')
# (50, 'Valkoinen suklaa', Decimal('16.25'), 'Karkki Oy')
# (76, 'Lakkalikööri', Decimal('18.00'), 'Karkki Oy')
# (49, 'Maxilaku', Decimal('20.00'), 'Karkki Oy')
# (42, 'Singaporean Hokkien Fried Mee', Decimal('14.00'), 'Leka Trading')
# (43, 'Ipoh Coffee', Decimal('46.00'), 'Leka Trading')
# (44, 'Gula Malacca', Decimal('19.45'), 'Leka Trading')
# (45, 'Rogede sild', Decimal('9.50'), 'Lyngbysild')
# (46, 'Spegesild', Decimal('12.00'), 'Lyngbysild')
# (55, 'Pâté chinois', Decimal('24.00'), 'Ma Maison')
# (54, 'Tourtière', Decimal('7.45'), 'Ma Maison')
# (15, 'Genen Shouyu', Decimal('15.50'), "Mayumi's")
# (13, 'Konbu', Decimal('6.00'), "Mayumi's")
# (14, 'Tofu', Decimal('23.25'), "Mayumi's")
# (40, 'Boston Crab Meat', Decimal('18.40'), 'New England Seafood Cannery')
# (41, "Jack's New England Clam Chowder", Decimal('9.65'), 'New England Seafood Cannery')
# (5, "Chef Anton's Gumbo Mix", Decimal('21.35'), 'New Orleans Ca6/Delights')
# (65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('21.05'), 'New Orleans Ca6/Delights')
# (4, "Chef Anton's Ca6/Seasoning", Decimal('22.00'), 'New Orleans Ca6/Delights')
# (66, 'Louisiana Hot Spiced Okra', Decimal('17.00'), 'New Orleans Ca6/Delights')
# (30, 'Nord-Ost Matjeshering', Decimal('25.89'), 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# (69, 'Gudbrandsdalsost', Decimal('36.00'), 'Norske Meierier')
# (33, 'Geitost', Decimal('2.50'), 'Norske Meierier')
# (71, 'Flotemysost', Decimal('21.50'), 'Norske Meierier')
# (57, 'Ravioli Angelo', Decimal('19.50'), 'Pasta Buttini s.r.l.')
# (56, 'Gnocchi di nonna Alice', Decimal('38.00'), 'Pasta Buttini s.r.l.')
# (18, 'Carnarvon Tigers', Decimal('62.50'), 'Pavlova, Ltd.')
# (70, 'Outback Lager', Decimal('15.00'), 'Pavlova, Ltd.')
# (16, 'Pavlova', Decimal('17.45'), 'Pavlova, Ltd.')
# (63, 'Vegie-spread', Decimal('43.90'), 'Pavlova, Ltd.')
# (17, 'Alice Mutton', Decimal('39.00'), 'Pavlova, Ltd.')
# (23, 'Tunnbröd', Decimal('9.00'), 'PB Knäckebröd AB')
# (22, "Gustaf's Knäckebröd", Decimal('21.00'), 'PB Knäckebröd AB')
# (77, 'Original Frankfurter grüne Soße', Decimal('13.00'), 'Plutzer Lebensmittelgroßmärkte AG')
# (28, 'Rössle Sauerkraut', Decimal('45.60'), 'Plutzer Lebensmittelgroßmärkte AG')
# (75, 'Rhönbräu Klosterbier', Decimal('7.75'), 'Plutzer Lebensmittelgroßmärkte AG')
# (29, 'Thüringer Rostbratwurst', Decimal('123.79'), 'Plutzer Lebensmittelgroßmärkte AG')
# (64, 'Wimmers gute Semmelknödel', Decimal('33.25'), 'Plutzer Lebensmittelgroßmärkte AG')
# (24, 'Guaraná Fantástica', Decimal('4.50'), 'Refrescos Americanas LTDA')
# (20, "Sir Rodney's Marmalade", Decimal('81.00'), 'Specialty Biscuits, Ltd.')
# (21, "Sir Rodney's Scones", Decimal('10.00'), 'Specialty Biscuits, Ltd.')
# (68, 'Scottish Longbreads', Decimal('12.50'), 'Specialty Biscuits, Ltd.')
# (19, 'Teatime Chocolate Biscuits', Decimal('9.20'), 'Specialty Biscuits, Ltd.')
# (37, 'Gravad lax', Decimal('26.00'), 'Svensk Sjöföda AB')
# (36, 'Inlagd Sill', Decimal('19.00'), 'Svensk Sjöföda AB')
# (73, 'Röd Kaviar', Decimal('15.00'), 'Svensk Sjöföda AB')
# (10, 'Ikura', Decimal('31.00'), 'Tokyo Traders')
# (74, 'Longlife Tofu', Decimal('10.00'), 'Tokyo Traders')
# (9, 'Mishi Kobe Niku', Decimal('97.00'), 'Tokyo Traders')
# (47, 'Zaanse koeken', Decimal('9.50'), 'Zaanse Snoepfabriek')
# (48, 'Chocolade', Decimal('12.75'), 'Zaanse Snoepfabriek')
# (78, 'Stroopwafels', Decimal('9.75'), 'Zaanse Snoepfabriek')
# **********************************************************************
# file name: EX3\02.sql
# SELECT o.Id, o.OrderDate, p.ProductName, i.Quantity, i.UnitPrice, i.Quantity*i.UnitPrice, CONCAT(c.FirstName, ' ', c.LastName)
# FROM orders o JOIN orderitems i ON o.Id=i.OrderId
# JOIN products p ON i.ProductId=p.Id
# JOIN customers c ON o.CustomerId=c.Id
# WHERE c.FirstName='Thomas' AND c.LastName='Hardy';
# **********************************************************************
# (108, datetime.datetime(2012, 11, 15, 0, 0), 'Guaraná Fantástica', 25, Decimal('3.60'), Decimal('90.00'), 'Thomas Hardy')
# (108, datetime.datetime(2012, 11, 15, 0, 0), 'Ravioli Angelo', 25, Decimal('15.60'), Decimal('390.00'), 'Thomas Hardy')
# (136, datetime.datetime(2012, 12, 16, 0, 0), 'Konbu', 20, Decimal('4.80'), Decimal('96.00'), 'Thomas Hardy')
# (136, datetime.datetime(2012, 12, 16, 0, 0), 'Valkoinen suklaa', 15, Decimal('13.00'), Decimal('195.00'), 'Thomas Hardy')
# (136, datetime.datetime(2012, 12, 16, 0, 0), 'Gnocchi di nonna Alice', 20, Decimal('30.40'), Decimal('608.00'), 'Thomas Hardy')
# (206, datetime.datetime(2013, 2, 21, 0, 0), 'Chocolade', 15, Decimal('10.20'), Decimal('153.00'), 'Thomas Hardy')
# (206, datetime.datetime(2013, 2, 21, 0, 0), 'Outback Lager', 25, Decimal('12.00'), Decimal('300.00'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Zaanse koeken', 25, Decimal('9.50'), Decimal('237.50'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Manjimup Dried Apples', 20, Decimal('53.00'), Decimal('1060.00'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Filo Mix', 30, Decimal('7.00'), Decimal('210.00'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Perth Pasties', 18, Decimal('32.80'), Decimal('590.40'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Röd Kaviar', 3, Decimal('15.00'), Decimal('45.00'), 'Thomas Hardy')
# (460, datetime.datetime(2013, 10, 16, 0, 0), 'Pâté chinois', 21, Decimal('24.00'), Decimal('504.00'), 'Thomas Hardy')
# (460, datetime.datetime(2013, 10, 16, 0, 0), 'Ravioli Angelo', 40, Decimal('19.50'), Decimal('780.00'), 'Thomas Hardy')
# (460, datetime.datetime(2013, 10, 16, 0, 0), 'Outback Lager', 28, Decimal('15.00'), Decimal('420.00'), 'Thomas Hardy')
# (494, datetime.datetime(2013, 11, 14, 0, 0), 'Chang', 15, Decimal('19.00'), Decimal('285.00'), 'Thomas Hardy')
# (496, datetime.datetime(2013, 11, 17, 0, 0), 'Spegesild', 28, Decimal('12.00'), Decimal('336.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), "Gustaf's Knäckebröd", 4, Decimal('21.00'), Decimal('84.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), 'Gorgonzola Telino', 50, Decimal('12.50'), Decimal('625.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), 'Camembert Pierrot', 15, Decimal('34.00'), Decimal('510.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), 'Flotemysost', 12, Decimal('21.50'), Decimal('258.00'), 'Thomas Hardy')
# (546, datetime.datetime(2013, 12, 24, 0, 0), "Jack's New England Clam Chowder", 14, Decimal('9.65'), Decimal('135.10'), 'Thomas Hardy')
# (546, datetime.datetime(2013, 12, 24, 0, 0), 'Filo Mix', 8, Decimal('7.00'), Decimal('56.00'), 'Thomas Hardy')
# (617, datetime.datetime(2014, 2, 2, 0, 0), 'Steeleye Stout', 4, Decimal('18.00'), Decimal('72.00'), 'Thomas Hardy')
# (617, datetime.datetime(2014, 2, 2, 0, 0), 'Laughing Lumberjack Lager', 15, Decimal('14.00'), Decimal('210.00'), 'Thomas Hardy')
# (673, datetime.datetime(2014, 3, 3, 0, 0), 'Valkoinen suklaa', 24, Decimal('16.25'), Decimal('390.00'), 'Thomas Hardy')
# (706, datetime.datetime(2014, 3, 16, 0, 0), "Sir Rodney's Marmalade", 50, Decimal('81.00'), Decimal('4050.00'), 'Thomas Hardy')
# (706, datetime.datetime(2014, 3, 16, 0, 0), 'Gorgonzola Telino', 50, Decimal('12.50'), Decimal('625.00'), 'Thomas Hardy')
# (769, datetime.datetime(2014, 4, 10, 0, 0), 'Gorgonzola Telino', 15, Decimal('12.50'), Decimal('187.50'), 'Thomas Hardy')
# (769, datetime.datetime(2014, 4, 10, 0, 0), 'Inlagd Sill', 16, Decimal('19.00'), Decimal('304.00'), 'Thomas Hardy')
# **********************************************************************
# file name: EX3\03.sql
# SELECT * FROM customers WHERE Id NOT IN (SELECT CustomerId FROM orders);
# **********************************************************************
# (22, 'Diego', 'Roel', 'Madrid', 'Spain', '(91) 555 94 44')
# (57, 'Marie', 'Bertrand', 'Paris', 'France', '(1) 42.34.22.66')
# **********************************************************************
# file name: EX3\04.sql
# SELECT * FROM suppliers WHERE Id IN (SELECT DISTINCT supplierId FROM products WHERE IsDiscontinued);
# **********************************************************************
# (2, 'New Orleans Ca6/Delights', 'Shelley Burke', None, 'New Orleans', 'USA', '(100) 555-4822', None)
# (4, 'Tokyo Traders', 'Yoshi Nagase', None, 'Tokyo', 'Japan', '(03) 3555-5011', None)
# (7, 'Pavlova, Ltd.', 'Ian Devling', None, 'Melbourne', 'Australia', '(03) 444-2343', '(03) 444-6588')
# (10, 'Refrescos Americanas LTDA', 'Carlos Diaz', None, 'Sao Paulo', 'Brazil', '(11) 555 4640', None)
# (12, 'Plutzer Lebensmittelgroßmärkte AG', 'Martin Bein', None, 'Frankfurt', 'Germany', '(069) 992755', None)
# (20, 'Leka Trading', 'Chandra Leka', None, 'Singapore', 'Singapore', '555-8787', None)
# (24, "G'day, Mate", 'Wendy Mackenzie', None, 'Sydney', 'Australia', '(02) 555-5914', '(02) 555-4873')
# **********************************************************************
# file name: EX3\05.sql
# SELECT 'customer' AS Type, Id AS ID, CONCAT(FirstName,' ',lastname) AS Name, City, Country, Phone
# FROM Customers WHERE Id NOT IN (SELECT CustomerId FROM orders)
# UNION ALL
# SELECT 'Supplier', id, companyname, City, Country, Phone
# FROM suppliers WHERE Id IN (SELECT DISTINCT supplierId FROM products WHERE IsDiscontinued);
# **********************************************************************
# ('customer', 22, 'Diego Roel', 'Madrid', 'Spain', '(91) 555 94 44')
# ('customer', 57, 'Marie Bertrand', 'Paris', 'France', '(1) 42.34.22.66')
# ('Supplier', 2, 'New Orleans Ca6/Delights', 'New Orleans', 'USA', '(100) 555-4822')
# ('Supplier', 4, 'Tokyo Traders', 'Tokyo', 'Japan', '(03) 3555-5011')
# ('Supplier', 7, 'Pavlova, Ltd.', 'Melbourne', 'Australia', '(03) 444-2343')
# ('Supplier', 10, 'Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil', '(11) 555 4640')
# ('Supplier', 12, 'Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany', '(069) 992755')
# ('Supplier', 20, 'Leka Trading', 'Singapore', 'Singapore', '555-8787')
# ('Supplier', 24, "G'day, Mate", 'Sydney', 'Australia', '(02) 555-5914')
# **********************************************************************
# file name: EX3\06.sql
# SELECT CONCAT(c.FirstName, ' ', c.LastName), o.Id, o.OrderDate
# FROM customers c LEFT JOIN orders o ON c.Id=o.CustomerId
# ORDER BY o.Id;
# **********************************************************************
# ('Marie Bertrand', None, None)
# ('Diego Roel', None, None)
# ('Paul Henriot', 1, datetime.datetime(2012, 7, 4, 0, 0))
# ('Karin Josephs', 2, datetime.datetime(2012, 7, 5, 0, 0))
# ('Mario Pontes', 3, datetime.datetime(2012, 7, 8, 0, 0))
# ('Mary Saveley', 4, datetime.datetime(2012, 7, 8, 0, 0))
# ('Pascale Cartrain', 5, datetime.datetime(2012, 7, 9, 0, 0))
# ('Mario Pontes', 6, datetime.datetime(2012, 7, 10, 0, 0))
# ('Yang Wang', 7, datetime.datetime(2012, 7, 11, 0, 0))
# ('Michael Holz', 8, datetime.datetime(2012, 7, 12, 0, 0))
# ('Paula Parente', 9, datetime.datetime(2012, 7, 15, 0, 0))
# ('Carlos Hernández', 10, datetime.datetime(2012, 7, 16, 0, 0))
# ('Roland Mendel', 11, datetime.datetime(2012, 7, 17, 0, 0))
# ('Francisco Chang', 12, datetime.datetime(2012, 7, 18, 0, 0))
# ('Henriette Pfalzheim', 13, datetime.datetime(2012, 7, 19, 0, 0))
# ('Bernardo Batista', 14, datetime.datetime(2012, 7, 19, 0, 0))
# ('Paula Wilson', 15, datetime.datetime(2012, 7, 22, 0, 0))
# ('Roland Mendel', 16, datetime.datetime(2012, 7, 23, 0, 0))
# ('Maria Larsson', 17, datetime.datetime(2012, 7, 24, 0, 0))
# ('Frédérique Citeaux', 18, datetime.datetime(2012, 7, 25, 0, 0))
# ('Pirkko Koskitalo', 19, datetime.datetime(2012, 7, 26, 0, 0))
# ('Peter Franken', 20, datetime.datetime(2012, 7, 29, 0, 0))
# ('Manuel Pereira', 21, datetime.datetime(2012, 7, 30, 0, 0))
# ('Karl Jablonski', 22, datetime.datetime(2012, 7, 31, 0, 0))
# ('Pirkko Koskitalo', 23, datetime.datetime(2012, 8, 1, 0, 0))
# ('Art Braunschweiger', 24, datetime.datetime(2012, 8, 1, 0, 0))
# ('Paula Wilson', 25, datetime.datetime(2012, 8, 2, 0, 0))
# ('Horst Kloss', 26, datetime.datetime(2012, 8, 5, 0, 0))
# ('Paul Henriot', 27, datetime.datetime(2012, 8, 6, 0, 0))
# ('Giovanni Rovelli', 28, datetime.datetime(2012, 8, 7, 0, 0))
# ('Miguel Angel Paolino', 29, datetime.datetime(2012, 8, 8, 0, 0))
# ('Alexander Feuer', 30, datetime.datetime(2012, 8, 9, 0, 0))
# ('Christina Berglund', 31, datetime.datetime(2012, 8, 12, 0, 0))
# ('Renate Messner', 32, datetime.datetime(2012, 8, 13, 0, 0))
# ('Christina Berglund', 33, datetime.datetime(2012, 8, 14, 0, 0))
# ('Alejandra Camino', 34, datetime.datetime(2012, 8, 14, 0, 0))
# ('Alejandra Camino', 35, datetime.datetime(2012, 8, 15, 0, 0))
# ('Carlos González', 36, datetime.datetime(2012, 8, 16, 0, 0))
# ('Renate Messner', 37, datetime.datetime(2012, 8, 19, 0, 0))
# ('Horst Kloss', 38, datetime.datetime(2012, 8, 20, 0, 0))
# ('Horst Kloss', 39, datetime.datetime(2012, 8, 21, 0, 0))
# ('Janete Limeira', 40, datetime.datetime(2012, 8, 22, 0, 0))
# ('Maurizio Moroni', 41, datetime.datetime(2012, 8, 23, 0, 0))
# ('Victoria Ashworth', 42, datetime.datetime(2012, 8, 26, 0, 0))
# ('Pedro Afonso', 43, datetime.datetime(2012, 8, 27, 0, 0))
# ('Bernardo Batista', 44, datetime.datetime(2012, 8, 27, 0, 0))
# ('Anabela Domingues', 45, datetime.datetime(2012, 8, 28, 0, 0))
# ('Miguel Angel Paolino', 46, datetime.datetime(2012, 8, 29, 0, 0))
# ('Paula Wilson', 47, datetime.datetime(2012, 8, 30, 0, 0))
# ('Paul Henriot', 48, datetime.datetime(2012, 9, 2, 0, 0))
# ('Carlos González', 49, datetime.datetime(2012, 9, 3, 0, 0))
# ('Frédérique Citeaux', 50, datetime.datetime(2012, 9, 4, 0, 0))
# ('Patricia McKenna', 51, datetime.datetime(2012, 9, 5, 0, 0))
# ('Janete Limeira', 52, datetime.datetime(2012, 9, 6, 0, 0))
# ('Giovanni Rovelli', 53, datetime.datetime(2012, 9, 9, 0, 0))
# ('Rita Müller', 54, datetime.datetime(2012, 9, 9, 0, 0))
# ('Pascale Cartrain', 55, datetime.datetime(2012, 9, 10, 0, 0))
# ('José Pedro Freyre', 56, datetime.datetime(2012, 9, 11, 0, 0))
# ('Miguel Angel Paolino', 57, datetime.datetime(2012, 9, 12, 0, 0))
# ('Rene Phillips', 58, datetime.datetime(2012, 9, 13, 0, 0))
# ('Alejandra Camino', 59, datetime.datetime(2012, 9, 16, 0, 0))
# ('Fran Wilson', 60, datetime.datetime(2012, 9, 17, 0, 0))
# ('Ana Trujillo', 61, datetime.datetime(2012, 9, 18, 0, 0))
# ('Patricia McKenna', 62, datetime.datetime(2012, 9, 19, 0, 0))
# ('Liz Nixon', 63, datetime.datetime(2012, 9, 20, 0, 0))
# ('Janine Labrune', 64, datetime.datetime(2012, 9, 20, 0, 0))
# ('Rita Müller', 65, datetime.datetime(2012, 9, 23, 0, 0))
# ('Horst Kloss', 66, datetime.datetime(2012, 9, 24, 0, 0))
# ('Paula Wilson', 67, datetime.datetime(2012, 9, 25, 0, 0))
# ('Helen Bennett', 68, datetime.datetime(2012, 9, 26, 0, 0))
# ('Paula Wilson', 69, datetime.datetime(2012, 9, 27, 0, 0))
# ('Fran Wilson', 70, datetime.datetime(2012, 9, 30, 0, 0))
# ('Helen Bennett', 71, datetime.datetime(2012, 10, 1, 0, 0))
# ('Miguel Angel Paolino', 72, datetime.datetime(2012, 10, 2, 0, 0))
# ('Pirkko Koskitalo', 73, datetime.datetime(2012, 10, 3, 0, 0))
# ('Helen Bennett', 74, datetime.datetime(2012, 10, 3, 0, 0))
# ('Guillermo Fernández', 75, datetime.datetime(2012, 10, 4, 0, 0))
# ('Philip Cramer', 76, datetime.datetime(2012, 10, 7, 0, 0))
# ('Jose Pavarotti', 77, datetime.datetime(2012, 10, 8, 0, 0))
# ('Philip Cramer', 78, datetime.datetime(2012, 10, 9, 0, 0))
# ('Martín Sommer', 79, datetime.datetime(2012, 10, 10, 0, 0))
# ('Maria Larsson', 80, datetime.datetime(2012, 10, 11, 0, 0))
# ('Lino Rodriguez', 81, datetime.datetime(2012, 10, 14, 0, 0))
# ('Art Braunschweiger', 82, datetime.datetime(2012, 10, 15, 0, 0))
# ('Carlos González', 83, datetime.datetime(2012, 10, 16, 0, 0))
# ('Laurence Lebihan', 84, datetime.datetime(2012, 10, 16, 0, 0))
# ('Jean Fresnière', 85, datetime.datetime(2012, 10, 17, 0, 0))
# ('Pirkko Koskitalo', 86, datetime.datetime(2012, 10, 18, 0, 0))
# ('Mary Saveley', 87, datetime.datetime(2012, 10, 21, 0, 0))
# ('Patricia McKenna', 88, datetime.datetime(2012, 10, 22, 0, 0))
# ('Isabel de Castro', 89, datetime.datetime(2012, 10, 23, 0, 0))
# ('Peter Franken', 90, datetime.datetime(2012, 10, 24, 0, 0))
# ('Rene Phillips', 91, datetime.datetime(2012, 10, 25, 0, 0))
# ('Jean Fresnière', 92, datetime.datetime(2012, 10, 28, 0, 0))
# ('Laurence Lebihan', 93, datetime.datetime(2012, 10, 29, 0, 0))
# ('Jytte Petersen', 94, datetime.datetime(2012, 10, 29, 0, 0))
# ('Peter Franken', 95, datetime.datetime(2012, 10, 30, 0, 0))
# ('Renate Messner', 96, datetime.datetime(2012, 10, 31, 0, 0))
# ('Karl Jablonski', 97, datetime.datetime(2012, 11, 1, 0, 0))
# ('Horst Kloss', 98, datetime.datetime(2012, 11, 4, 0, 0))
# ('Paula Wilson', 99, datetime.datetime(2012, 11, 5, 0, 0))
# ('Aria Cruz', 100, datetime.datetime(2012, 11, 6, 0, 0))
# ('Rita Müller', 101, datetime.datetime(2012, 11, 7, 0, 0))
# ('Art Braunschweiger', 102, datetime.datetime(2012, 11, 8, 0, 0))
# ('Annette Roulet', 103, datetime.datetime(2012, 11, 11, 0, 0))
# ('Roland Mendel', 104, datetime.datetime(2012, 11, 11, 0, 0))
# ('Lino Rodriguez', 105, datetime.datetime(2012, 11, 12, 0, 0))
# ('Georg Pipps', 106, datetime.datetime(2012, 11, 13, 0, 0))
# ('Guillermo Fernández', 107, datetime.datetime(2012, 11, 14, 0, 0))
# ('Thomas Hardy', 108, datetime.datetime(2012, 11, 15, 0, 0))
# ('Rita Müller', 109, datetime.datetime(2012, 11, 18, 0, 0))
# ('Carlos González', 110, datetime.datetime(2012, 11, 19, 0, 0))
# ('Annette Roulet', 111, datetime.datetime(2012, 11, 20, 0, 0))
# ('Hari Kumar', 112, datetime.datetime(2012, 11, 21, 0, 0))
# ('Frédérique Citeaux', 113, datetime.datetime(2012, 11, 22, 0, 0))
# ('Horst Kloss', 114, datetime.datetime(2012, 11, 22, 0, 0))
# ('Laurence Lebihan', 115, datetime.datetime(2012, 11, 25, 0, 0))
# ('Sven Ottlieb', 116, datetime.datetime(2012, 11, 26, 0, 0))
# ('Ann Devon', 117, datetime.datetime(2012, 11, 26, 0, 0))
# ('Antonio Moreno', 118, datetime.datetime(2012, 11, 27, 0, 0))
# ('Eduardo Saavedra', 119, datetime.datetime(2012, 11, 28, 0, 0))
# ('Palle Ibsen', 120, datetime.datetime(2012, 11, 28, 0, 0))
# ('Roland Mendel', 121, datetime.datetime(2012, 11, 29, 0, 0))
# ('Art Braunschweiger', 122, datetime.datetime(2012, 12, 2, 0, 0))
# ('Yang Wang', 123, datetime.datetime(2012, 12, 3, 0, 0))
# ('Annette Roulet', 124, datetime.datetime(2012, 12, 3, 0, 0))
# ('Lúcia Carvalho', 125, datetime.datetime(2012, 12, 4, 0, 0))
# ('Patricia McKenna', 126, datetime.datetime(2012, 12, 5, 0, 0))
# ('Zbyszek Piestrzeniewicz', 127, datetime.datetime(2012, 12, 5, 0, 0))
# ('Yoshi Latimer', 128, datetime.datetime(2012, 12, 6, 0, 0))
# ('Jean Fresnière', 129, datetime.datetime(2012, 12, 9, 0, 0))
# ('Hari Kumar', 130, datetime.datetime(2012, 12, 9, 0, 0))
# ('Maria Larsson', 131, datetime.datetime(2012, 12, 10, 0, 0))
# ('Bernardo Batista', 132, datetime.datetime(2012, 12, 11, 0, 0))
# ('Patricia McKenna', 133, datetime.datetime(2012, 12, 12, 0, 0))
# ('Carlos González', 134, datetime.datetime(2012, 12, 12, 0, 0))
# ('Roland Mendel', 135, datetime.datetime(2012, 12, 13, 0, 0))
# ('Thomas Hardy', 136, datetime.datetime(2012, 12, 16, 0, 0))
# ('Christina Berglund', 137, datetime.datetime(2012, 12, 16, 0, 0))
# ('Art Braunschweiger', 138, datetime.datetime(2012, 12, 17, 0, 0))
# ('Aria Cruz', 139, datetime.datetime(2012, 12, 18, 0, 0))
# ('Jonas Bergulfsen', 140, datetime.datetime(2012, 12, 18, 0, 0))
# ('Hari Kumar', 141, datetime.datetime(2012, 12, 19, 0, 0))
# ('Elizabeth Lincoln', 142, datetime.datetime(2012, 12, 20, 0, 0))
# ('Roland Mendel', 143, datetime.datetime(2012, 12, 23, 0, 0))
# ('Sven Ottlieb', 144, datetime.datetime(2012, 12, 23, 0, 0))
# ('Georg Pipps', 145, datetime.datetime(2012, 12, 24, 0, 0))
# ('Jose Pavarotti', 146, datetime.datetime(2012, 12, 25, 0, 0))
# ('Yoshi Latimer', 147, datetime.datetime(2012, 12, 25, 0, 0))
# ('Carlos Hernández', 148, datetime.datetime(2012, 12, 26, 0, 0))
# ('Peter Franken', 149, datetime.datetime(2012, 12, 27, 0, 0))
# ('Isabel de Castro', 150, datetime.datetime(2012, 12, 27, 0, 0))
# ('Jose Pavarotti', 151, datetime.datetime(2012, 12, 30, 0, 0))
# ('Palle Ibsen', 152, datetime.datetime(2012, 12, 31, 0, 0))
# ('Ann Devon', 153, datetime.datetime(2013, 1, 1, 0, 0))
# ('Paula Wilson', 154, datetime.datetime(2013, 1, 1, 0, 0))
# ('Roland Mendel', 155, datetime.datetime(2013, 1, 2, 0, 0))
# ('Roland Mendel', 156, datetime.datetime(2013, 1, 3, 0, 0))
# ('Giovanni Rovelli', 157, datetime.datetime(2013, 1, 3, 0, 0))
# ('Felipe Izquierdo', 158, datetime.datetime(2013, 1, 6, 0, 0))
# ('Lúcia Carvalho', 159, datetime.datetime(2013, 1, 7, 0, 0))
# ('Henriette Pfalzheim', 160, datetime.datetime(2013, 1, 7, 0, 0))
# ('Martine Rancé', 161, datetime.datetime(2013, 1, 8, 0, 0))
# ('Yvonne Moncada', 162, datetime.datetime(2013, 1, 9, 0, 0))
# ('Elizabeth Lincoln', 163, datetime.datetime(2013, 1, 10, 0, 0))
# ('Elizabeth Lincoln', 164, datetime.datetime(2013, 1, 10, 0, 0))
# ('Pirkko Koskitalo', 165, datetime.datetime(2013, 1, 13, 0, 0))
# ('Annette Roulet', 166, datetime.datetime(2013, 1, 14, 0, 0))
# ('Aria Cruz', 167, datetime.datetime(2013, 1, 14, 0, 0))
# ('Yoshi Latimer', 168, datetime.datetime(2013, 1, 15, 0, 0))
# ('Pirkko Koskitalo', 169, datetime.datetime(2013, 1, 16, 0, 0))
# ('Jytte Petersen', 170, datetime.datetime(2013, 1, 16, 0, 0))
# ('Horst Kloss', 171, datetime.datetime(2013, 1, 17, 0, 0))
# ('Michael Holz', 172, datetime.datetime(2013, 1, 20, 0, 0))
# ('Paula Parente', 173, datetime.datetime(2013, 1, 21, 0, 0))
# ('Bernardo Batista', 174, datetime.datetime(2013, 1, 21, 0, 0))
# ('Paolo Accorti', 175, datetime.datetime(2013, 1, 22, 0, 0))
# ('André Fonseca', 176, datetime.datetime(2013, 1, 23, 0, 0))
# ('Jean Fresnière', 177, datetime.datetime(2013, 1, 23, 0, 0))
# ('Annette Roulet', 178, datetime.datetime(2013, 1, 24, 0, 0))
# ('Eduardo Saavedra', 179, datetime.datetime(2013, 1, 27, 0, 0))
# ('Georg Pipps', 180, datetime.datetime(2013, 1, 27, 0, 0))
# ('Maurizio Moroni', 181, datetime.datetime(2013, 1, 28, 0, 0))
# ('Patricia McKenna', 182, datetime.datetime(2013, 1, 29, 0, 0))
# ('Roland Mendel', 183, datetime.datetime(2013, 1, 30, 0, 0))
# ('Elizabeth Lincoln', 184, datetime.datetime(2013, 1, 30, 0, 0))
# ('Art Braunschweiger', 185, datetime.datetime(2013, 1, 31, 0, 0))
# ('Isabel de Castro', 186, datetime.datetime(2013, 2, 3, 0, 0))
# ('Maria Larsson', 187, datetime.datetime(2013, 2, 3, 0, 0))
# ('Elizabeth Brown', 188, datetime.datetime(2013, 2, 4, 0, 0))
# ('Frédérique Citeaux', 189, datetime.datetime(2013, 2, 5, 0, 0))
# ('Pirkko Koskitalo', 190, datetime.datetime(2013, 2, 5, 0, 0))
# ('Karin Josephs', 191, datetime.datetime(2013, 2, 6, 0, 0))
# ('Jean Fresnière', 192, datetime.datetime(2013, 2, 7, 0, 0))
# ('Jose Pavarotti', 193, datetime.datetime(2013, 2, 10, 0, 0))
# ('Rene Phillips', 194, datetime.datetime(2013, 2, 10, 0, 0))
# ('Roland Mendel', 195, datetime.datetime(2013, 2, 11, 0, 0))
# ('Maurizio Moroni', 196, datetime.datetime(2013, 2, 12, 0, 0))
# ('Christina Berglund', 197, datetime.datetime(2013, 2, 12, 0, 0))
# ('Christina Berglund', 198, datetime.datetime(2013, 2, 13, 0, 0))
# ('Karin Josephs', 199, datetime.datetime(2013, 2, 14, 0, 0))
# ('Janete Limeira', 200, datetime.datetime(2013, 2, 14, 0, 0))
# ('Sergio Gutiérrez', 201, datetime.datetime(2013, 2, 17, 0, 0))
# ('Frédérique Citeaux', 202, datetime.datetime(2013, 2, 18, 0, 0))
# ('Mary Saveley', 203, datetime.datetime(2013, 2, 19, 0, 0))
# ('Horst Kloss', 204, datetime.datetime(2013, 2, 19, 0, 0))
# ('Jose Pavarotti', 205, datetime.datetime(2013, 2, 20, 0, 0))
# ('Thomas Hardy', 206, datetime.datetime(2013, 2, 21, 0, 0))
# ('Annette Roulet', 207, datetime.datetime(2013, 2, 21, 0, 0))
# ('Pirkko Koskitalo', 208, datetime.datetime(2013, 2, 24, 0, 0))
# ('Philip Cramer', 209, datetime.datetime(2013, 2, 25, 0, 0))
# ('Philip Cramer', 210, datetime.datetime(2013, 2, 25, 0, 0))
# ('Pascale Cartrain', 211, datetime.datetime(2013, 2, 26, 0, 0))
# ('Mary Saveley', 212, datetime.datetime(2013, 2, 27, 0, 0))
# ('Maria Larsson', 213, datetime.datetime(2013, 2, 28, 0, 0))
# ('Carlos González', 214, datetime.datetime(2013, 2, 28, 0, 0))
# ('Elizabeth Brown', 215, datetime.datetime(2013, 3, 3, 0, 0))
# ('Pascale Cartrain', 216, datetime.datetime(2013, 3, 4, 0, 0))
# ('Lino Rodriguez', 217, datetime.datetime(2013, 3, 4, 0, 0))
# ('Palle Ibsen', 218, datetime.datetime(2013, 3, 5, 0, 0))
# ('Pedro Afonso', 219, datetime.datetime(2013, 3, 6, 0, 0))
# ('Giovanni Rovelli', 220, datetime.datetime(2013, 3, 6, 0, 0))
# ('Philip Cramer', 221, datetime.datetime(2013, 3, 7, 0, 0))
# ('Karl Jablonski', 222, datetime.datetime(2013, 3, 10, 0, 0))
# ('Laurence Lebihan', 223, datetime.datetime(2013, 3, 11, 0, 0))
# ('Victoria Ashworth', 224, datetime.datetime(2013, 3, 11, 0, 0))
# ('Hari Kumar', 225, datetime.datetime(2013, 3, 12, 0, 0))
# ('Helen Bennett', 226, datetime.datetime(2013, 3, 13, 0, 0))
# ('Guillermo Fernández', 227, datetime.datetime(2013, 3, 13, 0, 0))
# ('Pascale Cartrain', 228, datetime.datetime(2013, 3, 14, 0, 0))
# ('Carlos Hernández', 229, datetime.datetime(2013, 3, 17, 0, 0))
# ('Isabel de Castro', 230, datetime.datetime(2013, 3, 17, 0, 0))
# ('Mary Saveley', 231, datetime.datetime(2013, 3, 18, 0, 0))
# ('Paula Wilson', 232, datetime.datetime(2013, 3, 19, 0, 0))
# ('Martine Rancé', 233, datetime.datetime(2013, 3, 20, 0, 0))
# ('Janete Limeira', 234, datetime.datetime(2013, 3, 20, 0, 0))
# ('John Steel', 235, datetime.datetime(2013, 3, 21, 0, 0))
# ('Karl Jablonski', 236, datetime.datetime(2013, 3, 24, 0, 0))
# ('Victoria Ashworth', 237, datetime.datetime(2013, 3, 24, 0, 0))
# ('Felipe Izquierdo', 238, datetime.datetime(2013, 3, 25, 0, 0))
# ('Carlos Hernández', 239, datetime.datetime(2013, 3, 26, 0, 0))
# ('Lúcia Carvalho', 240, datetime.datetime(2013, 3, 26, 0, 0))
# ('Peter Franken', 241, datetime.datetime(2013, 3, 27, 0, 0))
# ('Georg Pipps', 242, datetime.datetime(2013, 3, 28, 0, 0))
# ('Carlos Hernández', 243, datetime.datetime(2013, 3, 31, 0, 0))
# ('Lino Rodriguez', 244, datetime.datetime(2013, 3, 31, 0, 0))
# ('Elizabeth Lincoln', 245, datetime.datetime(2013, 4, 1, 0, 0))
# ('Annette Roulet', 246, datetime.datetime(2013, 4, 2, 0, 0))
# ('Pedro Afonso', 247, datetime.datetime(2013, 4, 2, 0, 0))
# ('Yoshi Tannamuri', 248, datetime.datetime(2013, 4, 3, 0, 0))
# ('Anabela Domingues', 249, datetime.datetime(2013, 4, 4, 0, 0))
# ('Renate Messner', 250, datetime.datetime(2013, 4, 4, 0, 0))
# ('Carlos Hernández', 251, datetime.datetime(2013, 4, 7, 0, 0))
# ('Carlos González', 252, datetime.datetime(2013, 4, 8, 0, 0))
# ('Annette Roulet', 253, datetime.datetime(2013, 4, 9, 0, 0))
# ('Hanna Moos', 254, datetime.datetime(2013, 4, 9, 0, 0))
# ('Guillermo Fernández', 255, datetime.datetime(2013, 4, 10, 0, 0))
# ('Patricia McKenna', 256, datetime.datetime(2013, 4, 11, 0, 0))
# ('Karl Jablonski', 257, datetime.datetime(2013, 4, 11, 0, 0))
# ('Jean Fresnière', 258, datetime.datetime(2013, 4, 14, 0, 0))
# ('Philip Cramer', 259, datetime.datetime(2013, 4, 15, 0, 0))
# ('Antonio Moreno', 260, datetime.datetime(2013, 4, 15, 0, 0))
# ('Henriette Pfalzheim', 261, datetime.datetime(2013, 4, 16, 0, 0))
# ('Hanna Moos', 262, datetime.datetime(2013, 4, 17, 0, 0))
# ('Jose Pavarotti', 263, datetime.datetime(2013, 4, 18, 0, 0))
# ('Laurence Lebihan', 264, datetime.datetime(2013, 4, 18, 0, 0))
# ('Aria Cruz', 265, datetime.datetime(2013, 4, 21, 0, 0))
# ('Rita Müller', 266, datetime.datetime(2013, 4, 22, 0, 0))
# ('Roland Mendel', 267, datetime.datetime(2013, 4, 22, 0, 0))
# ('Horst Kloss', 268, datetime.datetime(2013, 4, 23, 0, 0))
# ('Patricia McKenna', 269, datetime.datetime(2013, 4, 24, 0, 0))
# ('Simon Crowther', 270, datetime.datetime(2013, 4, 24, 0, 0))
# ('Miguel Angel Paolino', 271, datetime.datetime(2013, 4, 25, 0, 0))
# ('Yang Wang', 272, datetime.datetime(2013, 4, 28, 0, 0))
# ('Jonas Bergulfsen', 273, datetime.datetime(2013, 4, 29, 0, 0))
# ('Patricio Simpson', 274, datetime.datetime(2013, 4, 29, 0, 0))
# ('Renate Messner', 275, datetime.datetime(2013, 4, 30, 0, 0))
# ('Hari Kumar', 276, datetime.datetime(2013, 5, 1, 0, 0))
# ('Christina Berglund', 277, datetime.datetime(2013, 5, 1, 0, 0))
# ('Laurence Lebihan', 278, datetime.datetime(2013, 5, 2, 0, 0))
# ('Pirkko Koskitalo', 279, datetime.datetime(2013, 5, 5, 0, 0))
# ('Horst Kloss', 280, datetime.datetime(2013, 5, 5, 0, 0))
# ('Howard Snyder', 281, datetime.datetime(2013, 5, 6, 0, 0))
# ('Catherine Dewey', 282, datetime.datetime(2013, 5, 7, 0, 0))
# ('Georg Pipps', 283, datetime.datetime(2013, 5, 8, 0, 0))
# ('Yvonne Moncada', 284, datetime.datetime(2013, 5, 8, 0, 0))
# ('Ann Devon', 285, datetime.datetime(2013, 5, 9, 0, 0))
# ('Maria Larsson', 286, datetime.datetime(2013, 5, 12, 0, 0))
# ('Renate Messner', 287, datetime.datetime(2013, 5, 12, 0, 0))
# ('Antonio Moreno', 288, datetime.datetime(2013, 5, 13, 0, 0))
# ('Renate Messner', 289, datetime.datetime(2013, 5, 14, 0, 0))
# ('Michael Holz', 290, datetime.datetime(2013, 5, 14, 0, 0))
# ('Victoria Ashworth', 291, datetime.datetime(2013, 5, 15, 0, 0))
# ('Victoria Ashworth', 292, datetime.datetime(2013, 5, 16, 0, 0))
# ('Horst Kloss', 293, datetime.datetime(2013, 5, 19, 0, 0))
# ('Mario Pontes', 294, datetime.datetime(2013, 5, 19, 0, 0))
# ('Philip Cramer', 295, datetime.datetime(2013, 5, 20, 0, 0))
# ('Carlos González', 296, datetime.datetime(2013, 5, 21, 0, 0))
# ('Fran Wilson', 297, datetime.datetime(2013, 5, 21, 0, 0))
# ('John Steel', 298, datetime.datetime(2013, 5, 22, 0, 0))
# ('Mary Saveley', 299, datetime.datetime(2013, 5, 23, 0, 0))
# ('Hari Kumar', 300, datetime.datetime(2013, 5, 23, 0, 0))
# ('Karin Josephs', 301, datetime.datetime(2013, 5, 26, 0, 0))
# ('Horst Kloss', 302, datetime.datetime(2013, 5, 27, 0, 0))
# ('José Pedro Freyre', 303, datetime.datetime(2013, 5, 28, 0, 0))
# ('Lino Rodriguez', 304, datetime.datetime(2013, 5, 28, 0, 0))
# ('Carlos Hernández', 305, datetime.datetime(2013, 5, 29, 0, 0))
# ('Pirkko Koskitalo', 306, datetime.datetime(2013, 5, 30, 0, 0))
# ('Henriette Pfalzheim', 307, datetime.datetime(2013, 5, 30, 0, 0))
# ('Jose Pavarotti', 308, datetime.datetime(2013, 6, 2, 0, 0))
# ('Jytte Petersen', 309, datetime.datetime(2013, 6, 3, 0, 0))
# ('Renate Messner', 310, datetime.datetime(2013, 6, 3, 0, 0))
# ('Thomas Hardy', 311, datetime.datetime(2013, 6, 4, 0, 0))
# ('Frédérique Citeaux', 312, datetime.datetime(2013, 6, 5, 0, 0))
# ('Peter Franken', 313, datetime.datetime(2013, 6, 6, 0, 0))
# ('Maria Larsson', 314, datetime.datetime(2013, 6, 6, 0, 0))
# ('Maurizio Moroni', 315, datetime.datetime(2013, 6, 9, 0, 0))
# ('Janete Limeira', 316, datetime.datetime(2013, 6, 10, 0, 0))
# ('Paula Wilson', 317, datetime.datetime(2013, 6, 10, 0, 0))
# ('Jean Fresnière', 318, datetime.datetime(2013, 6, 11, 0, 0))
# ('Frédérique Citeaux', 319, datetime.datetime(2013, 6, 12, 0, 0))
# ('Patricia McKenna', 320, datetime.datetime(2013, 6, 12, 0, 0))
# ('Eduardo Saavedra', 321, datetime.datetime(2013, 6, 13, 0, 0))
# ('Paula Wilson', 322, datetime.datetime(2013, 6, 16, 0, 0))
# ('Jean Fresnière', 323, datetime.datetime(2013, 6, 17, 0, 0))
# ('Roland Mendel', 324, datetime.datetime(2013, 6, 17, 0, 0))
# ('Christina Berglund', 325, datetime.datetime(2013, 6, 18, 0, 0))
# ('Antonio Moreno', 326, datetime.datetime(2013, 6, 19, 0, 0))
# ('Helvetius Nagy', 327, datetime.datetime(2013, 6, 19, 0, 0))
# ('Alexander Feuer', 328, datetime.datetime(2013, 6, 20, 0, 0))
# ('Miguel Angel Paolino', 329, datetime.datetime(2013, 6, 23, 0, 0))
# ('Helvetius Nagy', 330, datetime.datetime(2013, 6, 23, 0, 0))
# ('Victoria Ashworth', 331, datetime.datetime(2013, 6, 24, 0, 0))
# ('Jaime Yorres', 332, datetime.datetime(2013, 6, 25, 0, 0))
# ('Henriette Pfalzheim', 333, datetime.datetime(2013, 6, 26, 0, 0))
# ('Aria Cruz', 334, datetime.datetime(2013, 6, 26, 0, 0))
# ('Hanna Moos', 335, datetime.datetime(2013, 6, 27, 0, 0))
# ('Pirkko Koskitalo', 336, datetime.datetime(2013, 6, 30, 0, 0))
# ('Frédérique Citeaux', 337, datetime.datetime(2013, 6, 30, 0, 0))
# ('Paula Parente', 338, datetime.datetime(2013, 7, 1, 0, 0))
# ('Maurizio Moroni', 339, datetime.datetime(2013, 7, 2, 0, 0))
# ('Bernardo Batista', 340, datetime.datetime(2013, 7, 2, 0, 0))
# ('Horst Kloss', 341, datetime.datetime(2013, 7, 3, 0, 0))
# ('Howard Snyder', 342, datetime.datetime(2013, 7, 4, 0, 0))
# ('Jean Fresnière', 343, datetime.datetime(2013, 7, 7, 0, 0))
# ('Palle Ibsen', 344, datetime.datetime(2013, 7, 7, 0, 0))
# ('Renate Messner', 345, datetime.datetime(2013, 7, 8, 0, 0))
# ('Renate Messner', 346, datetime.datetime(2013, 7, 9, 0, 0))
# ('Rene Phillips', 347, datetime.datetime(2013, 7, 9, 0, 0))
# ('Roland Mendel', 348, datetime.datetime(2013, 7, 10, 0, 0))
# ('Karl Jablonski', 349, datetime.datetime(2013, 7, 11, 0, 0))
# ('Georg Pipps', 350, datetime.datetime(2013, 7, 11, 0, 0))
# ('Paula Wilson', 351, datetime.datetime(2013, 7, 14, 0, 0))
# ('Victoria Ashworth', 352, datetime.datetime(2013, 7, 15, 0, 0))
# ('Yoshi Latimer', 353, datetime.datetime(2013, 7, 16, 0, 0))
# ('Carlos Hernández', 354, datetime.datetime(2013, 7, 16, 0, 0))
# ('Palle Ibsen', 355, datetime.datetime(2013, 7, 17, 0, 0))
# ('Jose Pavarotti', 356, datetime.datetime(2013, 7, 18, 0, 0))
# ('Lino Rodriguez', 357, datetime.datetime(2013, 7, 18, 0, 0))
# ('Jean Fresnière', 358, datetime.datetime(2013, 7, 21, 0, 0))
# ('Anabela Domingues', 359, datetime.datetime(2013, 7, 22, 0, 0))
# ('Jose Pavarotti', 360, datetime.datetime(2013, 7, 22, 0, 0))
# ('Karin Josephs', 361, datetime.datetime(2013, 7, 23, 0, 0))
# ('Janine Labrune', 362, datetime.datetime(2013, 7, 24, 0, 0))
# ('Annette Roulet', 363, datetime.datetime(2013, 7, 25, 0, 0))
# ('Zbyszek Piestrzeniewicz', 364, datetime.datetime(2013, 7, 25, 0, 0))
# ('Jose Pavarotti', 365, datetime.datetime(2013, 7, 28, 0, 0))
# ('Carlos Hernández', 366, datetime.datetime(2013, 7, 29, 0, 0))
# ('Hanna Moos', 367, datetime.datetime(2013, 7, 29, 0, 0))
# ('Matti Karttunen', 368, datetime.datetime(2013, 7, 30, 0, 0))
# ('Howard Snyder', 369, datetime.datetime(2013, 7, 31, 0, 0))
# ('Howard Snyder', 370, datetime.datetime(2013, 7, 31, 0, 0))
# ('Jean Fresnière', 371, datetime.datetime(2013, 8, 1, 0, 0))
# ('Jean Fresnière', 372, datetime.datetime(2013, 8, 4, 0, 0))
# ('Yoshi Tannamuri', 373, datetime.datetime(2013, 8, 5, 0, 0))
# ('Helen Bennett', 374, datetime.datetime(2013, 8, 5, 0, 0))
# ('Janete Limeira', 375, datetime.datetime(2013, 8, 6, 0, 0))
# ('Peter Franken', 376, datetime.datetime(2013, 8, 7, 0, 0))
# ('Liu Wong', 377, datetime.datetime(2013, 8, 7, 0, 0))
# ('Ana Trujillo', 378, datetime.datetime(2013, 8, 8, 0, 0))
# ('Christina Berglund', 379, datetime.datetime(2013, 8, 11, 0, 0))
# ('Jose Pavarotti', 380, datetime.datetime(2013, 8, 11, 0, 0))
# ('Frédérique Citeaux', 381, datetime.datetime(2013, 8, 12, 0, 0))
# ('José Pedro Freyre', 382, datetime.datetime(2013, 8, 12, 0, 0))
# ('Philip Cramer', 383, datetime.datetime(2013, 8, 13, 0, 0))
# ('Annette Roulet', 384, datetime.datetime(2013, 8, 14, 0, 0))
# ('Rita Müller', 385, datetime.datetime(2013, 8, 14, 0, 0))
# ('Roland Mendel', 386, datetime.datetime(2013, 8, 15, 0, 0))
# ('Martine Rancé', 387, datetime.datetime(2013, 8, 15, 0, 0))
# ('Giovanni Rovelli', 388, datetime.datetime(2013, 8, 18, 0, 0))
# ('Pirkko Koskitalo', 389, datetime.datetime(2013, 8, 19, 0, 0))
# ('Lúcia Carvalho', 390, datetime.datetime(2013, 8, 19, 0, 0))
# ('Felipe Izquierdo', 391, datetime.datetime(2013, 8, 20, 0, 0))
# ('Jonas Bergulfsen', 392, datetime.datetime(2013, 8, 20, 0, 0))
# ('Rita Müller', 393, datetime.datetime(2013, 8, 21, 0, 0))
# ('Carlos Hernández', 394, datetime.datetime(2013, 8, 22, 0, 0))
# ('Jytte Petersen', 395, datetime.datetime(2013, 8, 22, 0, 0))
# ('Maria Anders', 396, datetime.datetime(2013, 8, 25, 0, 0))
# ('Paula Parente', 397, datetime.datetime(2013, 8, 25, 0, 0))
# ('Mario Pontes', 398, datetime.datetime(2013, 8, 26, 0, 0))
# ('Patricia McKenna', 399, datetime.datetime(2013, 8, 27, 0, 0))
# ('Bernardo Batista', 400, datetime.datetime(2013, 8, 27, 0, 0))
# ('Janete Limeira', 401, datetime.datetime(2013, 8, 28, 0, 0))
# ('Catherine Dewey', 402, datetime.datetime(2013, 8, 28, 0, 0))
# ('Aria Cruz', 403, datetime.datetime(2013, 8, 29, 0, 0))
# ('Rita Müller', 404, datetime.datetime(2013, 9, 1, 0, 0))
# ('André Fonseca', 405, datetime.datetime(2013, 9, 1, 0, 0))
# ('Peter Franken', 406, datetime.datetime(2013, 9, 2, 0, 0))
# ('Christina Berglund', 407, datetime.datetime(2013, 9, 2, 0, 0))
# ('Maurizio Moroni', 408, datetime.datetime(2013, 9, 3, 0, 0))
# ('Howard Snyder', 409, datetime.datetime(2013, 9, 4, 0, 0))
# ('Jose Pavarotti', 410, datetime.datetime(2013, 9, 4, 0, 0))
# ('Horst Kloss', 411, datetime.datetime(2013, 9, 5, 0, 0))
# ('Lúcia Carvalho', 412, datetime.datetime(2013, 9, 5, 0, 0))
# ('Yoshi Latimer', 413, datetime.datetime(2013, 9, 8, 0, 0))
# ('Patricia McKenna', 414, datetime.datetime(2013, 9, 9, 0, 0))
# ('Fran Wilson', 415, datetime.datetime(2013, 9, 9, 0, 0))
# ('Laurence Lebihan', 416, datetime.datetime(2013, 9, 10, 0, 0))
# ('Lino Rodriguez', 417, datetime.datetime(2013, 9, 10, 0, 0))
# ('Fran Wilson', 418, datetime.datetime(2013, 9, 11, 0, 0))
# ('Michael Holz', 419, datetime.datetime(2013, 9, 12, 0, 0))
# ('Roland Mendel', 420, datetime.datetime(2013, 9, 12, 0, 0))
# ('Rita Müller', 421, datetime.datetime(2013, 9, 15, 0, 0))
# ('Jytte Petersen', 422, datetime.datetime(2013, 9, 15, 0, 0))
# ('Peter Franken', 423, datetime.datetime(2013, 9, 16, 0, 0))
# ('Carine Schmitt', 424, datetime.datetime(2013, 9, 17, 0, 0))
# ('Christina Berglund', 425, datetime.datetime(2013, 9, 17, 0, 0))
# ('Matti Karttunen', 426, datetime.datetime(2013, 9, 18, 0, 0))
# ('Helen Bennett', 427, datetime.datetime(2013, 9, 18, 0, 0))
# ('Peter Franken', 428, datetime.datetime(2013, 9, 19, 0, 0))
# ('Miguel Angel Paolino', 429, datetime.datetime(2013, 9, 22, 0, 0))
# ('Antonio Moreno', 430, datetime.datetime(2013, 9, 22, 0, 0))
# ('Jose Pavarotti', 431, datetime.datetime(2013, 9, 23, 0, 0))
# ('Frédérique Citeaux', 432, datetime.datetime(2013, 9, 23, 0, 0))
# ('Rene Phillips', 433, datetime.datetime(2013, 9, 24, 0, 0))
# ('Howard Snyder', 434, datetime.datetime(2013, 9, 25, 0, 0))
# ('Antonio Moreno', 435, datetime.datetime(2013, 9, 25, 0, 0))
# ('Janine Labrune', 436, datetime.datetime(2013, 9, 26, 0, 0))
# ('Henriette Pfalzheim', 437, datetime.datetime(2013, 9, 26, 0, 0))
# ('André Fonseca', 438, datetime.datetime(2013, 9, 29, 0, 0))
# ('Georg Pipps', 439, datetime.datetime(2013, 9, 30, 0, 0))
# ('Patricia McKenna', 440, datetime.datetime(2013, 9, 30, 0, 0))
# ('Palle Ibsen', 441, datetime.datetime(2013, 10, 1, 0, 0))
# ('Christina Berglund', 442, datetime.datetime(2013, 10, 1, 0, 0))
# ('Mario Pontes', 443, datetime.datetime(2013, 10, 2, 0, 0))
# ('Horst Kloss', 444, datetime.datetime(2013, 10, 3, 0, 0))
# ('Maria Anders', 445, datetime.datetime(2013, 10, 3, 0, 0))
# ('Karl Jablonski', 446, datetime.datetime(2013, 10, 6, 0, 0))
# ('Horst Kloss', 447, datetime.datetime(2013, 10, 6, 0, 0))
# ('Matti Karttunen', 448, datetime.datetime(2013, 10, 7, 0, 0))
# ('Karl Jablonski', 449, datetime.datetime(2013, 10, 8, 0, 0))
# ('Felipe Izquierdo', 450, datetime.datetime(2013, 10, 8, 0, 0))
# ('Roland Mendel', 451, datetime.datetime(2013, 10, 9, 0, 0))
# ('Alexander Feuer', 452, datetime.datetime(2013, 10, 9, 0, 0))
# ('Jose Pavarotti', 453, datetime.datetime(2013, 10, 10, 0, 0))
# ('Patricia McKenna', 454, datetime.datetime(2013, 10, 13, 0, 0))
# ('Maria Anders', 455, datetime.datetime(2013, 10, 13, 0, 0))
# ('Maria Larsson', 456, datetime.datetime(2013, 10, 14, 0, 0))
# ('Lúcia Carvalho', 457, datetime.datetime(2013, 10, 14, 0, 0))
# ('Carlos Hernández', 458, datetime.datetime(2013, 10, 15, 0, 0))
# ('Rene Phillips', 459, datetime.datetime(2013, 10, 16, 0, 0))
# ('Thomas Hardy', 460, datetime.datetime(2013, 10, 16, 0, 0))
# ('Liz Nixon', 461, datetime.datetime(2013, 10, 17, 0, 0))
# ('André Fonseca', 462, datetime.datetime(2013, 10, 17, 0, 0))
# ('Paolo Accorti', 463, datetime.datetime(2013, 10, 20, 0, 0))
# ('Jose Pavarotti', 464, datetime.datetime(2013, 10, 21, 0, 0))
# ('Patricia McKenna', 465, datetime.datetime(2013, 10, 21, 0, 0))
# ('Jose Pavarotti', 466, datetime.datetime(2013, 10, 22, 0, 0))
# ('Jose Pavarotti', 467, datetime.datetime(2013, 10, 22, 0, 0))
# ('Laurence Lebihan', 468, datetime.datetime(2013, 10, 23, 0, 0))
# ('Sergio Gutiérrez', 469, datetime.datetime(2013, 10, 24, 0, 0))
# ('Peter Franken', 470, datetime.datetime(2013, 10, 24, 0, 0))
# ('Philip Cramer', 471, datetime.datetime(2013, 10, 27, 0, 0))
# ('Jaime Yorres', 472, datetime.datetime(2013, 10, 27, 0, 0))
# ('Bernardo Batista', 473, datetime.datetime(2013, 10, 28, 0, 0))
# ('Horst Kloss', 474, datetime.datetime(2013, 10, 29, 0, 0))
# ('Jose Pavarotti', 475, datetime.datetime(2013, 10, 29, 0, 0))
# ('Karl Jablonski', 476, datetime.datetime(2013, 10, 30, 0, 0))
# ('Jean Fresnière', 477, datetime.datetime(2013, 10, 30, 0, 0))
# ('Aria Cruz', 478, datetime.datetime(2013, 10, 31, 0, 0))
# ('Ann Devon', 479, datetime.datetime(2013, 11, 3, 0, 0))
# ('Maurizio Moroni', 480, datetime.datetime(2013, 11, 3, 0, 0))
# ('Lúcia Carvalho', 481, datetime.datetime(2013, 11, 4, 0, 0))
# ('Felipe Izquierdo', 482, datetime.datetime(2013, 11, 4, 0, 0))
# ('Laurence Lebihan', 483, datetime.datetime(2013, 11, 5, 0, 0))
# ('Yang Wang', 484, datetime.datetime(2013, 11, 6, 0, 0))
# ('Laurence Lebihan', 485, datetime.datetime(2013, 11, 6, 0, 0))
# ('Christina Berglund', 486, datetime.datetime(2013, 11, 7, 0, 0))
# ('André Fonseca', 487, datetime.datetime(2013, 11, 7, 0, 0))
# ('Jaime Yorres', 488, datetime.datetime(2013, 11, 10, 0, 0))
# ('Patricia McKenna', 489, datetime.datetime(2013, 11, 11, 0, 0))
# ('Paul Henriot', 490, datetime.datetime(2013, 11, 11, 0, 0))
# ('Dominique Perrier', 491, datetime.datetime(2013, 11, 12, 0, 0))
# ('Paul Henriot', 492, datetime.datetime(2013, 11, 12, 0, 0))
# ('Karl Jablonski', 493, datetime.datetime(2013, 11, 13, 0, 0))
# ('Thomas Hardy', 494, datetime.datetime(2013, 11, 14, 0, 0))
# ('Elizabeth Lincoln', 495, datetime.datetime(2013, 11, 14, 0, 0))
# ('Thomas Hardy', 496, datetime.datetime(2013, 11, 17, 0, 0))
# ('Palle Ibsen', 497, datetime.datetime(2013, 11, 17, 0, 0))
# ('Horst Kloss', 498, datetime.datetime(2013, 11, 18, 0, 0))
# ('Yang Wang', 499, datetime.datetime(2013, 11, 19, 0, 0))
# ('Georg Pipps', 500, datetime.datetime(2013, 11, 19, 0, 0))
# ('Jose Pavarotti', 501, datetime.datetime(2013, 11, 20, 0, 0))
# ('Helen Bennett', 502, datetime.datetime(2013, 11, 20, 0, 0))
# ('Pirkko Koskitalo', 503, datetime.datetime(2013, 11, 21, 0, 0))
# ('Michael Holz', 504, datetime.datetime(2013, 11, 24, 0, 0))
# ('Simon Crowther', 505, datetime.datetime(2013, 11, 24, 0, 0))
# ('Paolo Accorti', 506, datetime.datetime(2013, 11, 25, 0, 0))
# ('Giovanni Rovelli', 507, datetime.datetime(2013, 11, 25, 0, 0))
# ('Laurence Lebihan', 508, datetime.datetime(2013, 11, 26, 0, 0))
# ('Art Braunschweiger', 509, datetime.datetime(2013, 11, 27, 0, 0))
# ('Jose Pavarotti', 510, datetime.datetime(2013, 11, 27, 0, 0))
# ('Michael Holz', 511, datetime.datetime(2013, 11, 28, 0, 0))
# ('Ana Trujillo', 512, datetime.datetime(2013, 11, 28, 0, 0))
# ('Catherine Dewey', 513, datetime.datetime(2013, 12, 1, 0, 0))
# ('Paula Wilson', 514, datetime.datetime(2013, 12, 2, 0, 0))
# ('Maria Larsson', 515, datetime.datetime(2013, 12, 2, 0, 0))
# ('Martine Rancé', 516, datetime.datetime(2013, 12, 3, 0, 0))
# ('Roland Mendel', 517, datetime.datetime(2013, 12, 3, 0, 0))
# ('Horst Kloss', 518, datetime.datetime(2013, 12, 4, 0, 0))
# ('Henriette Pfalzheim', 519, datetime.datetime(2013, 12, 5, 0, 0))
# ('Pascale Cartrain', 520, datetime.datetime(2013, 12, 5, 0, 0))
# ('Thomas Hardy', 521, datetime.datetime(2013, 12, 8, 0, 0))
# ('Palle Ibsen', 522, datetime.datetime(2013, 12, 8, 0, 0))
# ('Mario Pontes', 523, datetime.datetime(2013, 12, 9, 0, 0))
# ('Roland Mendel', 524, datetime.datetime(2013, 12, 10, 0, 0))
# ('Renate Messner', 525, datetime.datetime(2013, 12, 10, 0, 0))
# ('Roland Mendel', 526, datetime.datetime(2013, 12, 11, 0, 0))
# ('Maria Larsson', 527, datetime.datetime(2013, 12, 11, 0, 0))
# ('Liu Wong', 528, datetime.datetime(2013, 12, 12, 0, 0))
# ('Roland Mendel', 529, datetime.datetime(2013, 12, 15, 0, 0))
# ('André Fonseca', 530, datetime.datetime(2013, 12, 15, 0, 0))
# ('Christina Berglund', 531, datetime.datetime(2013, 12, 16, 0, 0))
# ('Alexander Feuer', 532, datetime.datetime(2013, 12, 16, 0, 0))
# ('Carlos González', 533, datetime.datetime(2013, 12, 16, 0, 0))
# ('Pirkko Koskitalo', 534, datetime.datetime(2013, 12, 17, 0, 0))
# ('Patricio Simpson', 535, datetime.datetime(2013, 12, 17, 0, 0))
# ('Mario Pontes', 536, datetime.datetime(2013, 12, 18, 0, 0))
# ('Giovanni Rovelli', 537, datetime.datetime(2013, 12, 18, 0, 0))
# ('Manuel Pereira', 538, datetime.datetime(2013, 12, 18, 0, 0))
# ('Lúcia Carvalho', 539, datetime.datetime(2013, 12, 19, 0, 0))
# ('Annette Roulet', 540, datetime.datetime(2013, 12, 19, 0, 0))
# ('Horst Kloss', 541, datetime.datetime(2013, 12, 22, 0, 0))
# ('Martine Rancé', 542, datetime.datetime(2013, 12, 22, 0, 0))
# ('André Fonseca', 543, datetime.datetime(2013, 12, 22, 0, 0))
# ('Peter Franken', 544, datetime.datetime(2013, 12, 23, 0, 0))
# ('Zbyszek Piestrzeniewicz', 545, datetime.datetime(2013, 12, 23, 0, 0))
# ('Thomas Hardy', 546, datetime.datetime(2013, 12, 24, 0, 0))
# ('Bernardo Batista', 547, datetime.datetime(2013, 12, 24, 0, 0))
# ('Roland Mendel', 548, datetime.datetime(2013, 12, 24, 0, 0))
# ('Carlos Hernández', 549, datetime.datetime(2013, 12, 25, 0, 0))
# ('Sven Ottlieb', 550, datetime.datetime(2013, 12, 25, 0, 0))
# ('Helen Bennett', 551, datetime.datetime(2013, 12, 26, 0, 0))
# ('Philip Cramer', 552, datetime.datetime(2013, 12, 26, 0, 0))
# ('Hari Kumar', 553, datetime.datetime(2013, 12, 26, 0, 0))
# ('Martín Sommer', 554, datetime.datetime(2013, 12, 29, 0, 0))
# ('Jytte Petersen', 555, datetime.datetime(2013, 12, 29, 0, 0))
# ('Paula Parente', 556, datetime.datetime(2013, 12, 30, 0, 0))
# ('Hari Kumar', 557, datetime.datetime(2013, 12, 30, 0, 0))
# ('Liz Nixon', 558, datetime.datetime(2013, 12, 30, 0, 0))
# ('Mary Saveley', 559, datetime.datetime(2013, 12, 31, 0, 0))
# ('Paolo Accorti', 560, datetime.datetime(2013, 12, 31, 0, 0))
# ('Rene Phillips', 561, datetime.datetime(2014, 1, 1, 0, 0))
# ('Paula Parente', 562, datetime.datetime(2014, 1, 1, 0, 0))
# ('Yoshi Tannamuri', 563, datetime.datetime(2014, 1, 1, 0, 0))
# ('Felipe Izquierdo', 564, datetime.datetime(2014, 1, 2, 0, 0))
# ('Maurizio Moroni', 565, datetime.datetime(2014, 1, 2, 0, 0))
# ('Janete Limeira', 566, datetime.datetime(2014, 1, 5, 0, 0))
# ('Mary Saveley', 567, datetime.datetime(2014, 1, 5, 0, 0))
# ('Jose Pavarotti', 568, datetime.datetime(2014, 1, 5, 0, 0))
# ('Howard Snyder', 569, datetime.datetime(2014, 1, 6, 0, 0))
# ('Philip Cramer', 570, datetime.datetime(2014, 1, 6, 0, 0))
# ('Giovanni Rovelli', 571, datetime.datetime(2014, 1, 7, 0, 0))
# ('Patricio Simpson', 572, datetime.datetime(2014, 1, 7, 0, 0))
# ('Paula Wilson', 573, datetime.datetime(2014, 1, 7, 0, 0))
# ('Art Braunschweiger', 574, datetime.datetime(2014, 1, 8, 0, 0))
# ('Helvetius Nagy', 575, datetime.datetime(2014, 1, 8, 0, 0))
# ('Carlos González', 576, datetime.datetime(2014, 1, 9, 0, 0))
# ('Maria Larsson', 577, datetime.datetime(2014, 1, 9, 0, 0))
# ('Sven Ottlieb', 578, datetime.datetime(2014, 1, 9, 0, 0))
# ('Frédérique Citeaux', 579, datetime.datetime(2014, 1, 12, 0, 0))
# ('Laurence Lebihan', 580, datetime.datetime(2014, 1, 12, 0, 0))
# ('Sergio Gutiérrez', 581, datetime.datetime(2014, 1, 13, 0, 0))
# ('Helen Bennett', 582, datetime.datetime(2014, 1, 13, 0, 0))
# ('Anabela Domingues', 583, datetime.datetime(2014, 1, 13, 0, 0))
# ('Jonas Bergulfsen', 584, datetime.datetime(2014, 1, 14, 0, 0))
# ('Annette Roulet', 585, datetime.datetime(2014, 1, 14, 0, 0))
# ('Henriette Pfalzheim', 586, datetime.datetime(2014, 1, 15, 0, 0))
# ('Anabela Domingues', 587, datetime.datetime(2014, 1, 15, 0, 0))
# ('Maria Anders', 588, datetime.datetime(2014, 1, 15, 0, 0))
# ('Roland Mendel', 589, datetime.datetime(2014, 1, 16, 0, 0))
# ('Christina Berglund', 590, datetime.datetime(2014, 1, 16, 0, 0))
# ('Felipe Izquierdo', 591, datetime.datetime(2014, 1, 19, 0, 0))
# ('Anabela Domingues', 592, datetime.datetime(2014, 1, 19, 0, 0))
# ('Felipe Izquierdo', 593, datetime.datetime(2014, 1, 19, 0, 0))
# ('Pascale Cartrain', 594, datetime.datetime(2014, 1, 20, 0, 0))
# ('Miguel Angel Paolino', 595, datetime.datetime(2014, 1, 20, 0, 0))
# ('Mary Saveley', 596, datetime.datetime(2014, 1, 21, 0, 0))
# ('Georg Pipps', 597, datetime.datetime(2014, 1, 21, 0, 0))
# ('Horst Kloss', 598, datetime.datetime(2014, 1, 21, 0, 0))
# ('Pascale Cartrain', 599, datetime.datetime(2014, 1, 22, 0, 0))
# ('Jose Pavarotti', 600, datetime.datetime(2014, 1, 22, 0, 0))
# ('Elizabeth Brown', 601, datetime.datetime(2014, 1, 23, 0, 0))
# ('Philip Cramer', 602, datetime.datetime(2014, 1, 23, 0, 0))
# ('Mary Saveley', 603, datetime.datetime(2014, 1, 23, 0, 0))
# ('Janete Limeira', 604, datetime.datetime(2014, 1, 26, 0, 0))
# ('Paula Wilson', 605, datetime.datetime(2014, 1, 26, 0, 0))
# ('Hanna Moos', 606, datetime.datetime(2014, 1, 27, 0, 0))
# ('Roland Mendel', 607, datetime.datetime(2014, 1, 27, 0, 0))
# ('Rene Phillips', 608, datetime.datetime(2014, 1, 27, 0, 0))
# ('Antonio Moreno', 609, datetime.datetime(2014, 1, 28, 0, 0))
# ('Christina Berglund', 610, datetime.datetime(2014, 1, 28, 0, 0))
# ('Daniel Tonini', 611, datetime.datetime(2014, 1, 29, 0, 0))
# ('Peter Franken', 612, datetime.datetime(2014, 1, 29, 0, 0))
# ('Carine Schmitt', 613, datetime.datetime(2014, 1, 29, 0, 0))
# ('Karl Jablonski', 614, datetime.datetime(2014, 1, 30, 0, 0))
# ('Renate Messner', 615, datetime.datetime(2014, 1, 30, 0, 0))
# ('Carlos Hernández', 616, datetime.datetime(2014, 2, 2, 0, 0))
# ('Thomas Hardy', 617, datetime.datetime(2014, 2, 2, 0, 0))
# ('Horst Kloss', 618, datetime.datetime(2014, 2, 2, 0, 0))
# ('Christina Berglund', 619, datetime.datetime(2014, 2, 3, 0, 0))
# ('Fran Wilson', 620, datetime.datetime(2014, 2, 3, 0, 0))
# ('Lúcia Carvalho', 621, datetime.datetime(2014, 2, 4, 0, 0))
# ('Hari Kumar', 622, datetime.datetime(2014, 2, 4, 0, 0))
# ('Zbyszek Piestrzeniewicz', 623, datetime.datetime(2014, 2, 4, 0, 0))
# ('Laurence Lebihan', 624, datetime.datetime(2014, 2, 5, 0, 0))
# ('José Pedro Freyre', 625, datetime.datetime(2014, 2, 5, 0, 0))
# ('Matti Karttunen', 626, datetime.datetime(2014, 2, 6, 0, 0))
# ('José Pedro Freyre', 627, datetime.datetime(2014, 2, 6, 0, 0))
# ('Christina Berglund', 628, datetime.datetime(2014, 2, 6, 0, 0))
# ('Laurence Lebihan', 629, datetime.datetime(2014, 2, 9, 0, 0))
# ('Janete Limeira', 630, datetime.datetime(2014, 2, 9, 0, 0))
# ('Horst Kloss', 631, datetime.datetime(2014, 2, 10, 0, 0))
# ('Matti Karttunen', 632, datetime.datetime(2014, 2, 10, 0, 0))
# ('Maria Larsson', 633, datetime.datetime(2014, 2, 10, 0, 0))
# ('Patricio Simpson', 634, datetime.datetime(2014, 2, 11, 0, 0))
# ('Jose Pavarotti', 635, datetime.datetime(2014, 2, 11, 0, 0))
# ('Fran Wilson', 636, datetime.datetime(2014, 2, 12, 0, 0))
# ('Jaime Yorres', 637, datetime.datetime(2014, 2, 12, 0, 0))
# ('Pascale Cartrain', 638, datetime.datetime(2014, 2, 12, 0, 0))
# ('Mario Pontes', 639, datetime.datetime(2014, 2, 13, 0, 0))
# ('Eduardo Saavedra', 640, datetime.datetime(2014, 2, 13, 0, 0))
# ('José Pedro Freyre', 641, datetime.datetime(2014, 2, 16, 0, 0))
# ('Paula Wilson', 642, datetime.datetime(2014, 2, 16, 0, 0))
# ('Janine Labrune', 643, datetime.datetime(2014, 2, 16, 0, 0))
# ('Renate Messner', 644, datetime.datetime(2014, 2, 17, 0, 0))
# ('Catherine Dewey', 645, datetime.datetime(2014, 2, 17, 0, 0))
# ('Philip Cramer', 646, datetime.datetime(2014, 2, 18, 0, 0))
# ('Jose Pavarotti', 647, datetime.datetime(2014, 2, 18, 0, 0))
# ('Roland Mendel', 648, datetime.datetime(2014, 2, 18, 0, 0))
# ('Catherine Dewey', 649, datetime.datetime(2014, 2, 19, 0, 0))
# ('Patricia McKenna', 650, datetime.datetime(2014, 2, 19, 0, 0))
# ('Yvonne Moncada', 651, datetime.datetime(2014, 2, 20, 0, 0))
# ('Carlos González', 652, datetime.datetime(2014, 2, 20, 0, 0))
# ('Paula Parente', 653, datetime.datetime(2014, 2, 20, 0, 0))
# ('Carlos Hernández', 654, datetime.datetime(2014, 2, 23, 0, 0))
# ('Maria Larsson', 655, datetime.datetime(2014, 2, 23, 0, 0))
# ('Mario Pontes', 656, datetime.datetime(2014, 2, 24, 0, 0))
# ('Karl Jablonski', 657, datetime.datetime(2014, 2, 24, 0, 0))
# ('Paula Parente', 658, datetime.datetime(2014, 2, 24, 0, 0))
# ('Zbyszek Piestrzeniewicz', 659, datetime.datetime(2014, 2, 25, 0, 0))
# ('Dominique Perrier', 660, datetime.datetime(2014, 2, 25, 0, 0))
# ('Maurizio Moroni', 661, datetime.datetime(2014, 2, 26, 0, 0))
# ('Jonas Bergulfsen', 662, datetime.datetime(2014, 2, 26, 0, 0))
# ('Matti Karttunen', 663, datetime.datetime(2014, 2, 26, 0, 0))
# ('José Pedro Freyre', 664, datetime.datetime(2014, 2, 26, 0, 0))
# ('Patricia McKenna', 665, datetime.datetime(2014, 2, 26, 0, 0))
# ('Lúcia Carvalho', 666, datetime.datetime(2014, 2, 26, 0, 0))
# ('Lúcia Carvalho', 667, datetime.datetime(2014, 2, 27, 0, 0))
# ('Miguel Angel Paolino', 668, datetime.datetime(2014, 2, 27, 0, 0))
# ('Sergio Gutiérrez', 669, datetime.datetime(2014, 2, 27, 0, 0))
# ('Alejandra Camino', 670, datetime.datetime(2014, 3, 2, 0, 0))
# ('Elizabeth Lincoln', 671, datetime.datetime(2014, 3, 2, 0, 0))
# ('Felipe Izquierdo', 672, datetime.datetime(2014, 3, 2, 0, 0))
# ('Thomas Hardy', 673, datetime.datetime(2014, 3, 3, 0, 0))
# ('Palle Ibsen', 674, datetime.datetime(2014, 3, 3, 0, 0))
# ('Mario Pontes', 675, datetime.datetime(2014, 3, 3, 0, 0))
# ('Annette Roulet', 676, datetime.datetime(2014, 3, 3, 0, 0))
# ('Christina Berglund', 677, datetime.datetime(2014, 3, 4, 0, 0))
# ('Mario Pontes', 678, datetime.datetime(2014, 3, 4, 0, 0))
# ('Ana Trujillo', 679, datetime.datetime(2014, 3, 4, 0, 0))
# ('Daniel Tonini', 680, datetime.datetime(2014, 3, 5, 0, 0))
# ('Eduardo Saavedra', 681, datetime.datetime(2014, 3, 5, 0, 0))
# ('Peter Franken', 682, datetime.datetime(2014, 3, 5, 0, 0))
# ('Pascale Cartrain', 683, datetime.datetime(2014, 3, 6, 0, 0))
# ('Michael Holz', 684, datetime.datetime(2014, 3, 6, 0, 0))
# ('Laurence Lebihan', 685, datetime.datetime(2014, 3, 6, 0, 0))
# ('Helen Bennett', 686, datetime.datetime(2014, 3, 6, 0, 0))
# ('Renate Messner', 687, datetime.datetime(2014, 3, 9, 0, 0))
# ('Paula Parente', 688, datetime.datetime(2014, 3, 9, 0, 0))
# ('Howard Snyder', 689, datetime.datetime(2014, 3, 9, 0, 0))
# ('Patricio Simpson', 690, datetime.datetime(2014, 3, 10, 0, 0))
# ('Horst Kloss', 691, datetime.datetime(2014, 3, 10, 0, 0))
# ('Giovanni Rovelli', 692, datetime.datetime(2014, 3, 10, 0, 0))
# ('Laurence Lebihan', 693, datetime.datetime(2014, 3, 11, 0, 0))
# ('Jose Pavarotti', 694, datetime.datetime(2014, 3, 11, 0, 0))
# ('Maurizio Moroni', 695, datetime.datetime(2014, 3, 11, 0, 0))
# ('Victoria Ashworth', 696, datetime.datetime(2014, 3, 11, 0, 0))
# ('Elizabeth Lincoln', 697, datetime.datetime(2014, 3, 12, 0, 0))
# ('Alexander Feuer', 698, datetime.datetime(2014, 3, 12, 0, 0))
# ('Palle Ibsen', 699, datetime.datetime(2014, 3, 12, 0, 0))
# ('Victoria Ashworth', 700, datetime.datetime(2014, 3, 13, 0, 0))
# ('José Pedro Freyre', 701, datetime.datetime(2014, 3, 13, 0, 0))
# ('Elizabeth Lincoln', 702, datetime.datetime(2014, 3, 13, 0, 0))
# ('Giovanni Rovelli', 703, datetime.datetime(2014, 3, 16, 0, 0))
# ('Michael Holz', 704, datetime.datetime(2014, 3, 16, 0, 0))
# ('Maria Anders', 705, datetime.datetime(2014, 3, 16, 0, 0))
# ('Thomas Hardy', 706, datetime.datetime(2014, 3, 16, 0, 0))
# ('Felipe Izquierdo', 707, datetime.datetime(2014, 3, 17, 0, 0))
# ('Maria Larsson', 708, datetime.datetime(2014, 3, 17, 0, 0))
# ('Hanna Moos', 709, datetime.datetime(2014, 3, 17, 0, 0))
# ('Carlos Hernández', 710, datetime.datetime(2014, 3, 18, 0, 0))
# ('Yvonne Moncada', 711, datetime.datetime(2014, 3, 18, 0, 0))
# ('André Fonseca', 712, datetime.datetime(2014, 3, 18, 0, 0))
# ('Carlos Hernández', 713, datetime.datetime(2014, 3, 19, 0, 0))
# ('Lúcia Carvalho', 714, datetime.datetime(2014, 3, 19, 0, 0))
# ('Horst Kloss', 715, datetime.datetime(2014, 3, 19, 0, 0))
# ('Lino Rodriguez', 716, datetime.datetime(2014, 3, 19, 0, 0))
# ('Dominique Perrier', 717, datetime.datetime(2014, 3, 20, 0, 0))
# ('Rene Phillips', 718, datetime.datetime(2014, 3, 20, 0, 0))
# ('Yang Wang', 719, datetime.datetime(2014, 3, 20, 0, 0))
# ('Karin Josephs', 720, datetime.datetime(2014, 3, 23, 0, 0))
# ('Roland Mendel', 721, datetime.datetime(2014, 3, 23, 0, 0))
# ('Pedro Afonso', 722, datetime.datetime(2014, 3, 23, 0, 0))
# ('Martín Sommer', 723, datetime.datetime(2014, 3, 24, 0, 0))
# ('Carine Schmitt', 724, datetime.datetime(2014, 3, 24, 0, 0))
# ('Daniel Tonini', 725, datetime.datetime(2014, 3, 24, 0, 0))
# ('Daniel Tonini', 726, datetime.datetime(2014, 3, 24, 0, 0))
# ('Art Braunschweiger', 727, datetime.datetime(2014, 3, 25, 0, 0))
# ('Elizabeth Lincoln', 728, datetime.datetime(2014, 3, 25, 0, 0))
# ('Carlos Hernández', 729, datetime.datetime(2014, 3, 25, 0, 0))
# ('Maria Larsson', 730, datetime.datetime(2014, 3, 26, 0, 0))
# ('Catherine Dewey', 731, datetime.datetime(2014, 3, 26, 0, 0))
# ('Roland Mendel', 732, datetime.datetime(2014, 3, 26, 0, 0))
# ('Maria Larsson', 733, datetime.datetime(2014, 3, 27, 0, 0))
# ('Mario Pontes', 734, datetime.datetime(2014, 3, 27, 0, 0))
# ('Elizabeth Lincoln', 735, datetime.datetime(2014, 3, 27, 0, 0))
# ('Jose Pavarotti', 736, datetime.datetime(2014, 3, 27, 0, 0))
# ('Jose Pavarotti', 737, datetime.datetime(2014, 3, 30, 0, 0))
# ('Patricia McKenna', 738, datetime.datetime(2014, 3, 30, 0, 0))
# ('Yvonne Moncada', 739, datetime.datetime(2014, 3, 30, 0, 0))
# ('Ann Devon', 740, datetime.datetime(2014, 3, 31, 0, 0))
# ('Paula Wilson', 741, datetime.datetime(2014, 3, 31, 0, 0))
# ('Bernardo Batista', 742, datetime.datetime(2014, 3, 31, 0, 0))
# ('Roland Mendel', 743, datetime.datetime(2014, 4, 1, 0, 0))
# ('Horst Kloss', 744, datetime.datetime(2014, 4, 1, 0, 0))
# ('Liz Nixon', 745, datetime.datetime(2014, 4, 1, 0, 0))
# ('Maria Larsson', 746, datetime.datetime(2014, 4, 1, 0, 0))
# ('Palle Ibsen', 747, datetime.datetime(2014, 4, 2, 0, 0))
# ('Guillermo Fernández', 748, datetime.datetime(2014, 4, 2, 0, 0))
# ('Horst Kloss', 749, datetime.datetime(2014, 4, 2, 0, 0))
# ('Carlos González', 750, datetime.datetime(2014, 4, 3, 0, 0))
# ('Zbyszek Piestrzeniewicz', 751, datetime.datetime(2014, 4, 3, 0, 0))
# ('Henriette Pfalzheim', 752, datetime.datetime(2014, 4, 3, 0, 0))
# ('Paula Wilson', 753, datetime.datetime(2014, 4, 6, 0, 0))
# ('Maria Larsson', 754, datetime.datetime(2014, 4, 6, 0, 0))
# ('Jose Pavarotti', 755, datetime.datetime(2014, 4, 6, 0, 0))
# ('Liu Wong', 756, datetime.datetime(2014, 4, 6, 0, 0))
# ('Catherine Dewey', 757, datetime.datetime(2014, 4, 7, 0, 0))
# ('Matti Karttunen', 758, datetime.datetime(2014, 4, 7, 0, 0))
# ('Howard Snyder', 759, datetime.datetime(2014, 4, 7, 0, 0))
# ('Isabel de Castro', 760, datetime.datetime(2014, 4, 8, 0, 0))
# ('Roland Mendel', 761, datetime.datetime(2014, 4, 8, 0, 0))
# ('José Pedro Freyre', 762, datetime.datetime(2014, 4, 8, 0, 0))
# ('Maurizio Moroni', 763, datetime.datetime(2014, 4, 9, 0, 0))
# ('Maria Anders', 764, datetime.datetime(2014, 4, 9, 0, 0))
# ('Peter Franken', 765, datetime.datetime(2014, 4, 9, 0, 0))
# ('Alejandra Camino', 766, datetime.datetime(2014, 4, 9, 0, 0))
# ('Felipe Izquierdo', 767, datetime.datetime(2014, 4, 10, 0, 0))
# ('Jonas Bergulfsen', 768, datetime.datetime(2014, 4, 10, 0, 0))
# ('Thomas Hardy', 769, datetime.datetime(2014, 4, 10, 0, 0))
# ('Roland Mendel', 770, datetime.datetime(2014, 4, 13, 0, 0))
# ('Fran Wilson', 771, datetime.datetime(2014, 4, 13, 0, 0))
# ('Sergio Gutiérrez', 772, datetime.datetime(2014, 4, 13, 0, 0))
# ('Henriette Pfalzheim', 773, datetime.datetime(2014, 4, 14, 0, 0))
# ('Horst Kloss', 774, datetime.datetime(2014, 4, 14, 0, 0))
# ('Mario Pontes', 775, datetime.datetime(2014, 4, 14, 0, 0))
# ('Victoria Ashworth', 776, datetime.datetime(2014, 4, 14, 0, 0))
# ('Ann Devon', 777, datetime.datetime(2014, 4, 15, 0, 0))
# ('Pirkko Koskitalo', 778, datetime.datetime(2014, 4, 15, 0, 0))
# ('Paolo Accorti', 779, datetime.datetime(2014, 4, 15, 0, 0))
# ('Elizabeth Lincoln', 780, datetime.datetime(2014, 4, 16, 0, 0))
# ('Philip Cramer', 781, datetime.datetime(2014, 4, 16, 0, 0))
# ('Yang Wang', 782, datetime.datetime(2014, 4, 16, 0, 0))
# ('Jose Pavarotti', 783, datetime.datetime(2014, 4, 17, 0, 0))
# ('Jose Pavarotti', 784, datetime.datetime(2014, 4, 17, 0, 0))
# ('Karl Jablonski', 785, datetime.datetime(2014, 4, 17, 0, 0))
# ('Michael Holz', 786, datetime.datetime(2014, 4, 17, 0, 0))
# ('Rene Phillips', 787, datetime.datetime(2014, 4, 20, 0, 0))
# ('Pascale Cartrain', 788, datetime.datetime(2014, 4, 20, 0, 0))
# ('Sven Ottlieb', 789, datetime.datetime(2014, 4, 20, 0, 0))
# ('José Pedro Freyre', 790, datetime.datetime(2014, 4, 21, 0, 0))
# ('Pascale Cartrain', 791, datetime.datetime(2014, 4, 21, 0, 0))
# ('Felipe Izquierdo', 792, datetime.datetime(2014, 4, 21, 0, 0))
# ('Howard Snyder', 793, datetime.datetime(2014, 4, 22, 0, 0))
# ('Yang Wang', 794, datetime.datetime(2014, 4, 22, 0, 0))
# ('Pedro Afonso', 795, datetime.datetime(2014, 4, 22, 0, 0))
# ('Dominique Perrier', 796, datetime.datetime(2014, 4, 22, 0, 0))
# ('Zbyszek Piestrzeniewicz', 797, datetime.datetime(2014, 4, 23, 0, 0))
# ('Elizabeth Lincoln', 798, datetime.datetime(2014, 4, 23, 0, 0))
# ('Rita Müller', 799, datetime.datetime(2014, 4, 23, 0, 0))
# ('Ann Devon', 800, datetime.datetime(2014, 4, 24, 0, 0))
# ('Elizabeth Lincoln', 801, datetime.datetime(2014, 4, 24, 0, 0))
# ('André Fonseca', 802, datetime.datetime(2014, 4, 24, 0, 0))
# ('Maria Larsson', 803, datetime.datetime(2014, 4, 27, 0, 0))
# ('Annette Roulet', 804, datetime.datetime(2014, 4, 27, 0, 0))
# ('Mario Pontes', 805, datetime.datetime(2014, 4, 27, 0, 0))
# ('Georg Pipps', 806, datetime.datetime(2014, 4, 27, 0, 0))
# ('Patricio Simpson', 807, datetime.datetime(2014, 4, 28, 0, 0))
# ('Carlos Hernández', 808, datetime.datetime(2014, 4, 28, 0, 0))
# ('Ann Devon', 809, datetime.datetime(2014, 4, 28, 0, 0))
# ('Simon Crowther', 810, datetime.datetime(2014, 4, 29, 0, 0))
# ('Hanna Moos', 811, datetime.datetime(2014, 4, 29, 0, 0))
# ('Janete Limeira', 812, datetime.datetime(2014, 4, 29, 0, 0))
# ('Paolo Accorti', 813, datetime.datetime(2014, 4, 30, 0, 0))
# ('Howard Snyder', 814, datetime.datetime(2014, 4, 30, 0, 0))
# ('Maurizio Moroni', 815, datetime.datetime(2014, 4, 30, 0, 0))
# ('Patricia McKenna', 816, datetime.datetime(2014, 4, 30, 0, 0))
# ('Jose Pavarotti', 817, datetime.datetime(2014, 5, 1, 0, 0))
# ('Carlos González', 818, datetime.datetime(2014, 5, 1, 0, 0))
# ('Karl Jablonski', 819, datetime.datetime(2014, 5, 1, 0, 0))
# ('Sven Ottlieb', 820, datetime.datetime(2014, 5, 4, 0, 0))
# ('Lúcia Carvalho', 821, datetime.datetime(2014, 5, 4, 0, 0))
# ('Miguel Angel Paolino', 822, datetime.datetime(2014, 5, 4, 0, 0))
# ('Renate Messner', 823, datetime.datetime(2014, 5, 5, 0, 0))
# ('Carlos González', 824, datetime.datetime(2014, 5, 5, 0, 0))
# ('Roland Mendel', 825, datetime.datetime(2014, 5, 5, 0, 0))
# ('Guillermo Fernández', 826, datetime.datetime(2014, 5, 5, 0, 0))
# ('Jytte Petersen', 827, datetime.datetime(2014, 5, 6, 0, 0))
# ('Michael Holz', 828, datetime.datetime(2014, 5, 6, 0, 0))
# ('Laurence Lebihan', 829, datetime.datetime(2014, 5, 6, 0, 0))
# ('Paula Wilson', 830, datetime.datetime(2014, 5, 6, 0, 0))

# %%
# Câu 1: Liệt kê danh sách sản phẩm theo từng nhà cung cấp, thông tin gồm ProductId, ProductName, UnitPrice, CompanyName
sql = """SELECT p.Id, p.ProductName, p.UnitPrice, s.CompanyName
FROM products p JOIN suppliers s ON p.SupplierId=s.Id
ORDER BY s.CompanyName;"""
run_sql(sql)
# Out:
# (38, 'Côte de Blaye', Decimal('263.50'), 'Aux joyeux ecclésiastiques')
# (39, 'Chartreuse verte', Decimal('18.00'), 'Aux joyeux ecclésiastiques')
# (35, 'Steeleye Stout', Decimal('18.00'), 'Bigfoot Breweries')
# (67, 'Laughing Lumberjack Lager', Decimal('14.00'), 'Bigfoot Breweries')
# (34, 'Sasquatch Ale', Decimal('14.00'), 'Bigfoot Breweries')
# (11, 'Queso Cabrales', Decimal('21.00'), "Cooperativa de Quesos 'Las Cabras'")
# (12, 'Queso Manchego La Pastora', Decimal('38.00'), "Cooperativa de Quesos 'Las Cabras'")
# (58, 'Escargots de Bourgogne', Decimal('13.25'), 'Escargots Nouveaux')
# (3, 'Aniseed Syrup', Decimal('10.00'), 'Exotic Liquids')
# (1, 'Chai', Decimal('18.00'), 'Exotic Liquids')
# (2, 'Chang', Decimal('19.00'), 'Exotic Liquids')
# (62, 'Tarte au sucre', Decimal('49.30'), "Forêts d'érables")
# (61, "Sirop d'érable", Decimal('28.50'), "Forêts d'érables")
# (72, 'Mozzarella di Giovanni', Decimal('34.80'), 'Formaggi Fortini s.r.l.')
# (31, 'Gorgonzola Telino', Decimal('12.50'), 'Formaggi Fortini s.r.l.')
# (32, 'Mascarpone Fabioli', Decimal('32.00'), 'Formaggi Fortini s.r.l.')
# (52, 'Filo Mix', Decimal('7.00'), "G'day, Mate")
# (53, 'Perth Pasties', Decimal('32.80'), "G'day, Mate")
# (51, 'Manjimup Dried Apples', Decimal('53.00'), "G'day, Mate")
# (60, 'Camembert Pierrot', Decimal('34.00'), 'Gai pâturage')
# (59, 'Raclette Courdavault', Decimal('55.00'), 'Gai pâturage')
# (8, 'Northwoods Cranberry Sauce', Decimal('40.00'), "Grandma Kelly's Homestead")
# (6, "Grandma's Boysenberry Spread", Decimal('25.00'), "Grandma Kelly's Homestead")
# (7, "Uncle Bob's Organic Dried Pears", Decimal('30.00'), "Grandma Kelly's Homestead")
# (25, 'NuNuCa Nuß-Nougat-Creme', Decimal('14.00'), 'Heli Süßwaren GmbH & Co. KG')
# (26, 'Gumbär Gummibärchen', Decimal('31.23'), 'Heli Süßwaren GmbH & Co. KG')
# (27, 'Schoggi Schokolade', Decimal('43.90'), 'Heli Süßwaren GmbH & Co. KG')
# (50, 'Valkoinen suklaa', Decimal('16.25'), 'Karkki Oy')
# (76, 'Lakkalikööri', Decimal('18.00'), 'Karkki Oy')
# (49, 'Maxilaku', Decimal('20.00'), 'Karkki Oy')
# (42, 'Singaporean Hokkien Fried Mee', Decimal('14.00'), 'Leka Trading')
# (43, 'Ipoh Coffee', Decimal('46.00'), 'Leka Trading')
# (44, 'Gula Malacca', Decimal('19.45'), 'Leka Trading')
# (45, 'Rogede sild', Decimal('9.50'), 'Lyngbysild')
# (46, 'Spegesild', Decimal('12.00'), 'Lyngbysild')
# (55, 'Pâté chinois', Decimal('24.00'), 'Ma Maison')
# (54, 'Tourtière', Decimal('7.45'), 'Ma Maison')
# (15, 'Genen Shouyu', Decimal('15.50'), "Mayumi's")
# (13, 'Konbu', Decimal('6.00'), "Mayumi's")
# (14, 'Tofu', Decimal('23.25'), "Mayumi's")
# (40, 'Boston Crab Meat', Decimal('18.40'), 'New England Seafood Cannery')
# (41, "Jack's New England Clam Chowder", Decimal('9.65'), 'New England Seafood Cannery')
# (5, "Chef Anton's Gumbo Mix", Decimal('21.35'), 'New Orleans Ca6/Delights')
# (65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('21.05'), 'New Orleans Ca6/Delights')
# (4, "Chef Anton's Ca6/Seasoning", Decimal('22.00'), 'New Orleans Ca6/Delights')
# (66, 'Louisiana Hot Spiced Okra', Decimal('17.00'), 'New Orleans Ca6/Delights')
# (30, 'Nord-Ost Matjeshering', Decimal('25.89'), 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# (69, 'Gudbrandsdalsost', Decimal('36.00'), 'Norske Meierier')
# (33, 'Geitost', Decimal('2.50'), 'Norske Meierier')
# (71, 'Flotemysost', Decimal('21.50'), 'Norske Meierier')
# (57, 'Ravioli Angelo', Decimal('19.50'), 'Pasta Buttini s.r.l.')
# (56, 'Gnocchi di nonna Alice', Decimal('38.00'), 'Pasta Buttini s.r.l.')
# (18, 'Carnarvon Tigers', Decimal('62.50'), 'Pavlova, Ltd.')
# (70, 'Outback Lager', Decimal('15.00'), 'Pavlova, Ltd.')
# (16, 'Pavlova', Decimal('17.45'), 'Pavlova, Ltd.')
# (63, 'Vegie-spread', Decimal('43.90'), 'Pavlova, Ltd.')
# (17, 'Alice Mutton', Decimal('39.00'), 'Pavlova, Ltd.')
# (23, 'Tunnbröd', Decimal('9.00'), 'PB Knäckebröd AB')
# (22, "Gustaf's Knäckebröd", Decimal('21.00'), 'PB Knäckebröd AB')
# (77, 'Original Frankfurter grüne Soße', Decimal('13.00'), 'Plutzer Lebensmittelgroßmärkte AG')
# (28, 'Rössle Sauerkraut', Decimal('45.60'), 'Plutzer Lebensmittelgroßmärkte AG')
# (75, 'Rhönbräu Klosterbier', Decimal('7.75'), 'Plutzer Lebensmittelgroßmärkte AG')
# (29, 'Thüringer Rostbratwurst', Decimal('123.79'), 'Plutzer Lebensmittelgroßmärkte AG')
# (64, 'Wimmers gute Semmelknödel', Decimal('33.25'), 'Plutzer Lebensmittelgroßmärkte AG')
# (24, 'Guaraná Fantástica', Decimal('4.50'), 'Refrescos Americanas LTDA')
# (20, "Sir Rodney's Marmalade", Decimal('81.00'), 'Specialty Biscuits, Ltd.')
# (21, "Sir Rodney's Scones", Decimal('10.00'), 'Specialty Biscuits, Ltd.')
# (68, 'Scottish Longbreads', Decimal('12.50'), 'Specialty Biscuits, Ltd.')
# (19, 'Teatime Chocolate Biscuits', Decimal('9.20'), 'Specialty Biscuits, Ltd.')
# (37, 'Gravad lax', Decimal('26.00'), 'Svensk Sjöföda AB')
# (36, 'Inlagd Sill', Decimal('19.00'), 'Svensk Sjöföda AB')
# (73, 'Röd Kaviar', Decimal('15.00'), 'Svensk Sjöföda AB')
# (10, 'Ikura', Decimal('31.00'), 'Tokyo Traders')
# (74, 'Longlife Tofu', Decimal('10.00'), 'Tokyo Traders')
# (9, 'Mishi Kobe Niku', Decimal('97.00'), 'Tokyo Traders')
# (47, 'Zaanse koeken', Decimal('9.50'), 'Zaanse Snoepfabriek')
# (48, 'Chocolade', Decimal('12.75'), 'Zaanse Snoepfabriek')
# (78, 'Stroopwafels', Decimal('9.75'), 'Zaanse Snoepfabriek')

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>(38, 'Côte de Blaye', Decimal('263.50'), 'Aux joyeux ecclésiastiques')
# (39, 'Chartreuse verte', Decimal('18.00'), 'Aux joyeux ecclésiastiques')
# (35, 'Steeleye Stout', Decimal('18.00'), 'Bigfoot Breweries')
# (67, 'Laughing Lumberjack Lager', Decimal('14.00'), 'Bigfoot Breweries')
# (34, 'Sasquatch Ale', Decimal('14.00'), 'Bigfoot Breweries')
# (11, 'Queso Cabrales', Decimal('21.00'), "Cooperativa de Quesos 'Las Cabras'")
# (12, 'Queso Manchego La Pastora', Decimal('38.00'), "Cooperativa de Quesos 'Las Cabras'")
# (58, 'Escargots de Bourgogne', Decimal('13.25'), 'Escargots Nouveaux')
# (3, 'Aniseed Syrup', Decimal('10.00'), 'Exotic Liquids')
# (1, 'Chai', Decimal('18.00'), 'Exotic Liquids')
# (2, 'Chang', Decimal('19.00'), 'Exotic Liquids')
# (62, 'Tarte au sucre', Decimal('49.30'), "Forêts d'érables")
# (61, "Sirop d'érable", Decimal('28.50'), "Forêts d'érables")
# (72, 'Mozzarella di Giovanni', Decimal('34.80'), 'Formaggi Fortini s.r.l.')
# (31, 'Gorgonzola Telino', Decimal('12.50'), 'Formaggi Fortini s.r.l.')
# (32, 'Mascarpone Fabioli', Decimal('32.00'), 'Formaggi Fortini s.r.l.')
# (52, 'Filo Mix', Decimal('7.00'), "G'day, Mate")
# (53, 'Perth Pasties', Decimal('32.80'), "G'day, Mate")
# (51, 'Manjimup Dried Apples', Decimal('53.00'), "G'day, Mate")
# (60, 'Camembert Pierrot', Decimal('34.00'), 'Gai pâturage')
# (59, 'Raclette Courdavault', Decimal('55.00'), 'Gai pâturage')
# (8, 'Northwoods Cranberry Sauce', Decimal('40.00'), "Grandma Kelly's Homestead")
# (6, "Grandma's Boysenberry Spread", Decimal('25.00'), "Grandma Kelly's Homestead")
# (7, "Uncle Bob's Organic Dried Pears", Decimal('30.00'), "Grandma Kelly's Homestead")
# (25, 'NuNuCa Nuß-Nougat-Creme', Decimal('14.00'), 'Heli Süßwaren GmbH &amp; Co. KG')
# (26, 'Gumbär Gummibärchen', Decimal('31.23'), 'Heli Süßwaren GmbH &amp; Co. KG')
# (27, 'Schoggi Schokolade', Decimal('43.90'), 'Heli Süßwaren GmbH &amp; Co. KG')
# (50, 'Valkoinen suklaa', Decimal('16.25'), 'Karkki Oy')
# (76, 'Lakkalikööri', Decimal('18.00'), 'Karkki Oy')
# (49, 'Maxilaku', Decimal('20.00'), 'Karkki Oy')
# (42, 'Singaporean Hokkien Fried Mee', Decimal('14.00'), 'Leka Trading')
# (43, 'Ipoh Coffee', Decimal('46.00'), 'Leka Trading')
# (44, 'Gula Malacca', Decimal('19.45'), 'Leka Trading')
# (45, 'Rogede sild', Decimal('9.50'), 'Lyngbysild')
# (46, 'Spegesild', Decimal('12.00'), 'Lyngbysild')
# (55, 'Pâté chinois', Decimal('24.00'), 'Ma Maison')
# (54, 'Tourtière', Decimal('7.45'), 'Ma Maison')
# (15, 'Genen Shouyu', Decimal('15.50'), "Mayumi's")
# (13, 'Konbu', Decimal('6.00'), "Mayumi's")
# (14, 'Tofu', Decimal('23.25'), "Mayumi's")
# (40, 'Boston Crab Meat', Decimal('18.40'), 'New England Seafood Cannery')
# (41, "Jack's New England Clam Chowder", Decimal('9.65'), 'New England Seafood Cannery')
# (5, "Chef Anton's Gumbo Mix", Decimal('21.35'), 'New Orleans Ca6/Delights')
# (65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('21.05'), 'New Orleans Ca6/Delights')
# (4, "Chef Anton's Ca6/Seasoning", Decimal('22.00'), 'New Orleans Ca6/Delights')
# (66, 'Louisiana Hot Spiced Okra', Decimal('17.00'), 'New Orleans Ca6/Delights')
# (30, 'Nord-Ost Matjeshering', Decimal('25.89'), 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# (69, 'Gudbrandsdalsost', Decimal('36.00'), 'Norske Meierier')
# (33, 'Geitost', Decimal('2.50'), 'Norske Meierier')
# (71, 'Flotemysost', Decimal('21.50'), 'Norske Meierier')
# (57, 'Ravioli Angelo', Decimal('19.50'), 'Pasta Buttini s.r.l.')
# (56, 'Gnocchi di nonna Alice', Decimal('38.00'), 'Pasta Buttini s.r.l.')
# (18, 'Carnarvon Tigers', Decimal('62.50'), 'Pavlova, Ltd.')
# (70, 'Outback Lager', Decimal('15.00'), 'Pavlova, Ltd.')
# (16, 'Pavlova', Decimal('17.45'), 'Pavlova, Ltd.')
# (63, 'Vegie-spread', Decimal('43.90'), 'Pavlova, Ltd.')
# (17, 'Alice Mutton', Decimal('39.00'), 'Pavlova, Ltd.')
# (23, 'Tunnbröd', Decimal('9.00'), 'PB Knäckebröd AB')
# (22, "Gustaf's Knäckebröd", Decimal('21.00'), 'PB Knäckebröd AB')
# (77, 'Original Frankfurter grüne Soße', Decimal('13.00'), 'Plutzer Lebensmittelgroßmärkte AG')
# (28, 'Rössle Sauerkraut', Decimal('45.60'), 'Plutzer Lebensmittelgroßmärkte AG')
# (75, 'Rhönbräu Klosterbier', Decimal('7.75'), 'Plutzer Lebensmittelgroßmärkte AG')
# (29, 'Thüringer Rostbratwurst', Decimal('123.79'), 'Plutzer Lebensmittelgroßmärkte AG')
# (64, 'Wimmers gute Semmelknödel', Decimal('33.25'), 'Plutzer Lebensmittelgroßmärkte AG')
# (24, 'Guaraná Fantástica', Decimal('4.50'), 'Refrescos Americanas LTDA')
# (20, "Sir Rodney's Marmalade", Decimal('81.00'), 'Specialty Biscuits, Ltd.')
# (21, "Sir Rodney's Scones", Decimal('10.00'), 'Specialty Biscuits, Ltd.')
# (68, 'Scottish Longbreads', Decimal('12.50'), 'Specialty Biscuits, Ltd.')
# (19, 'Teatime Chocolate Biscuits', Decimal('9.20'), 'Specialty Biscuits, Ltd.')
# (37, 'Gravad lax', Decimal('26.00'), 'Svensk Sjöföda AB')
# (36, 'Inlagd Sill', Decimal('19.00'), 'Svensk Sjöföda AB')
# (73, 'Röd Kaviar', Decimal('15.00'), 'Svensk Sjöföda AB')
# (10, 'Ikura', Decimal('31.00'), 'Tokyo Traders')
# (74, 'Longlife Tofu', Decimal('10.00'), 'Tokyo Traders')
# (9, 'Mishi Kobe Niku', Decimal('97.00'), 'Tokyo Traders')
# (47, 'Zaanse koeken', Decimal('9.50'), 'Zaanse Snoepfabriek')
# (48, 'Chocolade', Decimal('12.75'), 'Zaanse Snoepfabriek')
# (78, 'Stroopwafels', Decimal('9.75'), 'Zaanse Snoepfabriek')
# </pre>
#
# </details>

# %%
# Câu 2: Liệt danh sách các sản phẩm được đặt hàng bởi 'Thomas Hardy'
# Thông tin gồm: Order_Id, OrderDate, ProductName, Quantity, SalePrice và CustomerName
# Trong đó SalePrice = UnitPrice * Quantity
sql = """SELECT o.Id, o.OrderDate, p.ProductName, i.Quantity, i.UnitPrice, i.Quantity*i.UnitPrice, CONCAT(c.FirstName, ' ', c.LastName)
FROM orders o JOIN orderitems i ON o.Id=i.OrderId
JOIN products p ON i.ProductId=p.Id
JOIN customers c ON o.CustomerId=c.Id
WHERE c.FirstName='Thomas' AND c.LastName='Hardy';"""
run_sql(sql)
# Out:
# (108, datetime.datetime(2012, 11, 15, 0, 0), 'Guaraná Fantástica', 25, Decimal('3.60'), Decimal('90.00'), 'Thomas Hardy')
# (108, datetime.datetime(2012, 11, 15, 0, 0), 'Ravioli Angelo', 25, Decimal('15.60'), Decimal('390.00'), 'Thomas Hardy')
# (136, datetime.datetime(2012, 12, 16, 0, 0), 'Konbu', 20, Decimal('4.80'), Decimal('96.00'), 'Thomas Hardy')
# (136, datetime.datetime(2012, 12, 16, 0, 0), 'Valkoinen suklaa', 15, Decimal('13.00'), Decimal('195.00'), 'Thomas Hardy')
# (136, datetime.datetime(2012, 12, 16, 0, 0), 'Gnocchi di nonna Alice', 20, Decimal('30.40'), Decimal('608.00'), 'Thomas Hardy')
# (206, datetime.datetime(2013, 2, 21, 0, 0), 'Chocolade', 15, Decimal('10.20'), Decimal('153.00'), 'Thomas Hardy')
# (206, datetime.datetime(2013, 2, 21, 0, 0), 'Outback Lager', 25, Decimal('12.00'), Decimal('300.00'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Zaanse koeken', 25, Decimal('9.50'), Decimal('237.50'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Manjimup Dried Apples', 20, Decimal('53.00'), Decimal('1060.00'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Filo Mix', 30, Decimal('7.00'), Decimal('210.00'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Perth Pasties', 18, Decimal('32.80'), Decimal('590.40'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Röd Kaviar', 3, Decimal('15.00'), Decimal('45.00'), 'Thomas Hardy')
# (460, datetime.datetime(2013, 10, 16, 0, 0), 'Pâté chinois', 21, Decimal('24.00'), Decimal('504.00'), 'Thomas Hardy')
# (460, datetime.datetime(2013, 10, 16, 0, 0), 'Ravioli Angelo', 40, Decimal('19.50'), Decimal('780.00'), 'Thomas Hardy')
# (460, datetime.datetime(2013, 10, 16, 0, 0), 'Outback Lager', 28, Decimal('15.00'), Decimal('420.00'), 'Thomas Hardy')
# (494, datetime.datetime(2013, 11, 14, 0, 0), 'Chang', 15, Decimal('19.00'), Decimal('285.00'), 'Thomas Hardy')
# (496, datetime.datetime(2013, 11, 17, 0, 0), 'Spegesild', 28, Decimal('12.00'), Decimal('336.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), "Gustaf's Knäckebröd", 4, Decimal('21.00'), Decimal('84.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), 'Gorgonzola Telino', 50, Decimal('12.50'), Decimal('625.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), 'Camembert Pierrot', 15, Decimal('34.00'), Decimal('510.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), 'Flotemysost', 12, Decimal('21.50'), Decimal('258.00'), 'Thomas Hardy')
# (546, datetime.datetime(2013, 12, 24, 0, 0), "Jack's New England Clam Chowder", 14, Decimal('9.65'), Decimal('135.10'), 'Thomas Hardy')
# (546, datetime.datetime(2013, 12, 24, 0, 0), 'Filo Mix', 8, Decimal('7.00'), Decimal('56.00'), 'Thomas Hardy')
# (617, datetime.datetime(2014, 2, 2, 0, 0), 'Steeleye Stout', 4, Decimal('18.00'), Decimal('72.00'), 'Thomas Hardy')
# (617, datetime.datetime(2014, 2, 2, 0, 0), 'Laughing Lumberjack Lager', 15, Decimal('14.00'), Decimal('210.00'), 'Thomas Hardy')
# (673, datetime.datetime(2014, 3, 3, 0, 0), 'Valkoinen suklaa', 24, Decimal('16.25'), Decimal('390.00'), 'Thomas Hardy')
# (706, datetime.datetime(2014, 3, 16, 0, 0), "Sir Rodney's Marmalade", 50, Decimal('81.00'), Decimal('4050.00'), 'Thomas Hardy')
# (706, datetime.datetime(2014, 3, 16, 0, 0), 'Gorgonzola Telino', 50, Decimal('12.50'), Decimal('625.00'), 'Thomas Hardy')
# (769, datetime.datetime(2014, 4, 10, 0, 0), 'Gorgonzola Telino', 15, Decimal('12.50'), Decimal('187.50'), 'Thomas Hardy')
# (769, datetime.datetime(2014, 4, 10, 0, 0), 'Inlagd Sill', 16, Decimal('19.00'), Decimal('304.00'), 'Thomas Hardy')

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>(108, datetime.datetime(2012, 11, 15, 0, 0), 'Guaraná Fantástica', 25, Decimal('3.60'), Decimal('90.00'), 'Thomas Hardy')
# (108, datetime.datetime(2012, 11, 15, 0, 0), 'Ravioli Angelo', 25, Decimal('15.60'), Decimal('390.00'), 'Thomas Hardy')
# (136, datetime.datetime(2012, 12, 16, 0, 0), 'Konbu', 20, Decimal('4.80'), Decimal('96.00'), 'Thomas Hardy')
# (136, datetime.datetime(2012, 12, 16, 0, 0), 'Valkoinen suklaa', 15, Decimal('13.00'), Decimal('195.00'), 'Thomas Hardy')
# (136, datetime.datetime(2012, 12, 16, 0, 0), 'Gnocchi di nonna Alice', 20, Decimal('30.40'), Decimal('608.00'), 'Thomas Hardy')
# (206, datetime.datetime(2013, 2, 21, 0, 0), 'Chocolade', 15, Decimal('10.20'), Decimal('153.00'), 'Thomas Hardy')
# (206, datetime.datetime(2013, 2, 21, 0, 0), 'Outback Lager', 25, Decimal('12.00'), Decimal('300.00'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Zaanse koeken', 25, Decimal('9.50'), Decimal('237.50'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Manjimup Dried Apples', 20, Decimal('53.00'), Decimal('1060.00'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Filo Mix', 30, Decimal('7.00'), Decimal('210.00'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Perth Pasties', 18, Decimal('32.80'), Decimal('590.40'), 'Thomas Hardy')
# (311, datetime.datetime(2013, 6, 4, 0, 0), 'Röd Kaviar', 3, Decimal('15.00'), Decimal('45.00'), 'Thomas Hardy')
# (460, datetime.datetime(2013, 10, 16, 0, 0), 'Pâté chinois', 21, Decimal('24.00'), Decimal('504.00'), 'Thomas Hardy')
# (460, datetime.datetime(2013, 10, 16, 0, 0), 'Ravioli Angelo', 40, Decimal('19.50'), Decimal('780.00'), 'Thomas Hardy')
# (460, datetime.datetime(2013, 10, 16, 0, 0), 'Outback Lager', 28, Decimal('15.00'), Decimal('420.00'), 'Thomas Hardy')
# (494, datetime.datetime(2013, 11, 14, 0, 0), 'Chang', 15, Decimal('19.00'), Decimal('285.00'), 'Thomas Hardy')
# (496, datetime.datetime(2013, 11, 17, 0, 0), 'Spegesild', 28, Decimal('12.00'), Decimal('336.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), "Gustaf's Knäckebröd", 4, Decimal('21.00'), Decimal('84.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), 'Gorgonzola Telino', 50, Decimal('12.50'), Decimal('625.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), 'Camembert Pierrot', 15, Decimal('34.00'), Decimal('510.00'), 'Thomas Hardy')
# (521, datetime.datetime(2013, 12, 8, 0, 0), 'Flotemysost', 12, Decimal('21.50'), Decimal('258.00'), 'Thomas Hardy')
# (546, datetime.datetime(2013, 12, 24, 0, 0), "Jack's New England Clam Chowder", 14, Decimal('9.65'), Decimal('135.10'), 'Thomas Hardy')
# (546, datetime.datetime(2013, 12, 24, 0, 0), 'Filo Mix', 8, Decimal('7.00'), Decimal('56.00'), 'Thomas Hardy')
# (617, datetime.datetime(2014, 2, 2, 0, 0), 'Steeleye Stout', 4, Decimal('18.00'), Decimal('72.00'), 'Thomas Hardy')
# (617, datetime.datetime(2014, 2, 2, 0, 0), 'Laughing Lumberjack Lager', 15, Decimal('14.00'), Decimal('210.00'), 'Thomas Hardy')
# (673, datetime.datetime(2014, 3, 3, 0, 0), 'Valkoinen suklaa', 24, Decimal('16.25'), Decimal('390.00'), 'Thomas Hardy')
# (706, datetime.datetime(2014, 3, 16, 0, 0), "Sir Rodney's Marmalade", 50, Decimal('81.00'), Decimal('4050.00'), 'Thomas Hardy')
# (706, datetime.datetime(2014, 3, 16, 0, 0), 'Gorgonzola Telino', 50, Decimal('12.50'), Decimal('625.00'), 'Thomas Hardy')
# (769, datetime.datetime(2014, 4, 10, 0, 0), 'Gorgonzola Telino', 15, Decimal('12.50'), Decimal('187.50'), 'Thomas Hardy')
# (769, datetime.datetime(2014, 4, 10, 0, 0), 'Inlagd Sill', 16, Decimal('19.00'), Decimal('304.00'), 'Thomas Hardy')
# </pre>
#
# </details>

# %%
# Câu 3: Liệt kê danh sách các khách hàng chưa có đơn đặt hàng nào
sql = "SELECT * FROM customers WHERE Id NOT IN (SELECT CustomerId FROM orders);"
run_sql(sql)
# Out:
# (22, 'Diego', 'Roel', 'Madrid', 'Spain', '(91) 555 94 44')
# (57, 'Marie', 'Bertrand', 'Paris', 'France', '(1) 42.34.22.66')

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>(22, 'Diego', 'Roel', 'Madrid', 'Spain', '(91) 555 94 44')
# (57, 'Marie', 'Bertrand', 'Paris', 'France', '(1) 42.34.22.66')
# </pre>
#
# </details>

# %%
# Câu 4: Liệt kê danh sách các nhà cung cấp có sản phẩm ngưng bán
sql = "SELECT * FROM suppliers WHERE Id IN (SELECT DISTINCT supplierId FROM products WHERE IsDiscontinued);"
run_sql(sql)
# Out:
# (2, 'New Orleans Ca6/Delights', 'Shelley Burke', None, 'New Orleans', 'USA', '(100) 555-4822', None)
# (4, 'Tokyo Traders', 'Yoshi Nagase', None, 'Tokyo', 'Japan', '(03) 3555-5011', None)
# (7, 'Pavlova, Ltd.', 'Ian Devling', None, 'Melbourne', 'Australia', '(03) 444-2343', '(03) 444-6588')
# (10, 'Refrescos Americanas LTDA', 'Carlos Diaz', None, 'Sao Paulo', 'Brazil', '(11) 555 4640', None)
# (12, 'Plutzer Lebensmittelgroßmärkte AG', 'Martin Bein', None, 'Frankfurt', 'Germany', '(069) 992755', None)
# (20, 'Leka Trading', 'Chandra Leka', None, 'Singapore', 'Singapore', '555-8787', None)
# (24, "G'day, Mate", 'Wendy Mackenzie', None, 'Sydney', 'Australia', '(02) 555-5914', '(02) 555-4873')

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>(2, 'New Orleans Ca6/Delights', 'Shelley Burke', None, 'New Orleans', 'USA', '(100) 555-4822', None)
# (4, 'Tokyo Traders', 'Yoshi Nagase', None, 'Tokyo', 'Japan', '(03) 3555-5011', None)
# (7, 'Pavlova, Ltd.', 'Ian Devling', None, 'Melbourne', 'Australia', '(03) 444-2343', '(03) 444-6588')
# (10, 'Refrescos Americanas LTDA', 'Carlos Diaz', None, 'Sao Paulo', 'Brazil', '(11) 555 4640', None)
# (12, 'Plutzer Lebensmittelgroßmärkte AG', 'Martin Bein', None, 'Frankfurt', 'Germany', '(069) 992755', None)
# (20, 'Leka Trading', 'Chandra Leka', None, 'Singapore', 'Singapore', '555-8787', None)
# (24, "G'day, Mate", 'Wendy Mackenzie', None, 'Sydney', 'Australia', '(02) 555-5914', '(02) 555-4873')
# </pre>
#
# </details>

# %%
# Câu 5: Liệt kê danh sách các khách hàng chưa có đơn đặt hàng nào và các nhà cung cấp có sản phẩm ngưng bán
# Thông tin gồm: Type, Id, Name, City, Country, Phone
# Trong đó: 
#          + Type: cho biết đó là Customer hay Supplier
#          + Id: hiển thị Id của Customer hoặc Id của Supplier tùy theo Type
#          + Name: hiển thị CustomerName hoặc CompanyName tùy theo Type

sql = """SELECT 'customer' AS Type, Id AS ID, CONCAT(FirstName,' ',lastname) AS Name, City, Country, Phone
FROM Customers WHERE Id NOT IN (SELECT CustomerId FROM orders)
UNION ALL
SELECT 'Supplier', id, companyname, City, Country, Phone
FROM suppliers WHERE Id IN (SELECT DISTINCT supplierId FROM products WHERE IsDiscontinued);"""
run_sql(sql)
# Out:
# ('customer', 22, 'Diego Roel', 'Madrid', 'Spain', '(91) 555 94 44')
# ('customer', 57, 'Marie Bertrand', 'Paris', 'France', '(1) 42.34.22.66')
# ('Supplier', 2, 'New Orleans Ca6/Delights', 'New Orleans', 'USA', '(100) 555-4822')
# ('Supplier', 4, 'Tokyo Traders', 'Tokyo', 'Japan', '(03) 3555-5011')
# ('Supplier', 7, 'Pavlova, Ltd.', 'Melbourne', 'Australia', '(03) 444-2343')
# ('Supplier', 10, 'Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil', '(11) 555 4640')
# ('Supplier', 12, 'Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany', '(069) 992755')
# ('Supplier', 20, 'Leka Trading', 'Singapore', 'Singapore', '555-8787')
# ('Supplier', 24, "G'day, Mate", 'Sydney', 'Australia', '(02) 555-5914')

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>('customer', 22, 'Diego Roel', 'Madrid', 'Spain', '(91) 555 94 44')
# ('customer', 57, 'Marie Bertrand', 'Paris', 'France', '(1) 42.34.22.66')
# ('Supplier', 2, 'New Orleans Ca6/Delights', 'New Orleans', 'USA', '(100) 555-4822')
# ('Supplier', 4, 'Tokyo Traders', 'Tokyo', 'Japan', '(03) 3555-5011')
# ('Supplier', 7, 'Pavlova, Ltd.', 'Melbourne', 'Australia', '(03) 444-2343')
# ('Supplier', 10, 'Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil', '(11) 555 4640')
# ('Supplier', 12, 'Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany', '(069) 992755')
# ('Supplier', 20, 'Leka Trading', 'Singapore', 'Singapore', '555-8787')
# ('Supplier', 24, "G'day, Mate", 'Sydney', 'Australia', '(02) 555-5914')
# </pre>
#
# </details>

# %%
# Câu 6: Liệt kê thông tin đặt hàng của các khách hàng (kể cả các khách hàng chưa có đặt hàng), chỉ liệt kê 10 dòng đầu tiên.
sql = """SELECT CONCAT(c.FirstName, ' ', c.LastName), o.Id, o.OrderDate
FROM customers c LEFT JOIN orders o ON c.Id=o.CustomerId
ORDER BY o.Id
LIMIT 10;"""
run_sql(sql)
# Out:
# ('Marie Bertrand', None, None)
# ('Diego Roel', None, None)
# ('Paul Henriot', 1, datetime.datetime(2012, 7, 4, 0, 0))
# ('Karin Josephs', 2, datetime.datetime(2012, 7, 5, 0, 0))
# ('Mario Pontes', 3, datetime.datetime(2012, 7, 8, 0, 0))
# ('Mary Saveley', 4, datetime.datetime(2012, 7, 8, 0, 0))
# ('Pascale Cartrain', 5, datetime.datetime(2012, 7, 9, 0, 0))
# ('Mario Pontes', 6, datetime.datetime(2012, 7, 10, 0, 0))
# ('Yang Wang', 7, datetime.datetime(2012, 7, 11, 0, 0))
# ('Michael Holz', 8, datetime.datetime(2012, 7, 12, 0, 0))

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>('Marie Bertrand', None, None)
# ('Diego Roel', None, None)
# ('Paul Henriot', 1, datetime.datetime(2012, 7, 4, 0, 0))
# ('Karin Josephs', 2, datetime.datetime(2012, 7, 5, 0, 0))
# ('Mario Pontes', 3, datetime.datetime(2012, 7, 8, 0, 0))
# ('Mary Saveley', 4, datetime.datetime(2012, 7, 8, 0, 0))
# ('Pascale Cartrain', 5, datetime.datetime(2012, 7, 9, 0, 0))
# ('Mario Pontes', 6, datetime.datetime(2012, 7, 10, 0, 0))
# ('Yang Wang', 7, datetime.datetime(2012, 7, 11, 0, 0))
# ('Michael Holz', 8, datetime.datetime(2012, 7, 12, 0, 0))
# </pre>
#
# </details>

# %%
conn.close()

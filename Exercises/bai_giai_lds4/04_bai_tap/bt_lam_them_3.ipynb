# %% [markdown]
# # Chapter 5 - Exercise 1: GroupBy

# %% [markdown]
# #### drinks.csv là tập tin cung cấp dữ liệu về tình hình tiêu thụ rượu bia ở các quốc gia theo từng châu lục
#
# country: tên quốc gia tiêu thụ<br/>
# beer_servings: số lượng bia tiêu thụ<br/>
# spirit_servings: số lượng rượu mạnh (>= 40<sup>0</sup>)<br/>
# wine_servings: số lượng rượu vang<br/>
# total_litres_of_pure_alcohol: tổng số lít rượu nguyên chất<br/>
# continent: châu lục

# %%
import pandas as pd
from sqlalchemy.engine import create_engine

# %%
user = 'hv'
password = '123456'
connection_string = "mysql+pymysql://{user}:{password}@172.24.40.247:3306/testdb?charset=UTF8".format(user=user, password=password)

# %%
engine = create_engine(connection_string)

# %%
# Câu 1: Đọc dữ liệu từ tập tin drinks.csv với index_col là cột đầu tiên của dữ liệu, và lưu vào biến drink. 
drinks = pd.read_sql('select * from drinks', engine)
# Cho biết kiểu dữ liệu (type) của drink
print(type(drinks))
# Cho biết ra kích thước (shape) của drink 
print(drinks.shape)
# Hiển thị tên các cột (columns) của drink
print(drinks.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (193, 7)
# Index(['id', 'country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
# Xem 5 dòng dữ liệu đầu tiên (head) của drink
drinks.head()
# Out:
#    id      country  beer_servings  spirit_servings  wine_servings  \
# 0   0  Afghanistan              0                0              0
# 1   1      Albania             89              132             54
# 2   2      Algeria             25                0             14
# 3   3      Andorra            245              138            312
# 4   4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# Xem 5 dòng dữ liệu cuối cùng (tail) của drink
drinks.tail()
# Out:
#       id    country  beer_servings  spirit_servings  wine_servings  \
# 188  188  Venezuela            333              100              3
# 189  189    Vietnam            111                2              1
# 190  190      Yemen              6                0              0
# 191  191     Zambia             32               19              4
# 192  192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
# Câu 2: Cho biết số lượng bia tiêu thụ trung bình ở mỗi châu lục
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
#       145.434783
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
# Câu 3: Cho biết thông tin thống kê tổng quát (describe) số lượng rượu vang được tiêu thụ ở mỗi châu lục 
drinks.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
#             23.0   24.521739  28.266378  1.0   5.0   11.0   34.00  100.0
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
# Câu 4: Cho biết số lượng các loại bia và rượu tiêu thụ trung bình (mean) ở mỗi châu lục
drinks.groupby('continent').mean()
# Out:
#                    id  beer_servings  spirit_servings  wine_servings  \
# continent
#             79.869565     145.434783       165.739130      24.521739
# AF          93.396226      61.471698        16.339623      16.264151
# AS         109.000000      37.045455        60.840909       9.068182
# EU          89.377778     193.777778       132.555556     142.222222
# OC         117.312500      89.687500        58.437500      35.625000
# SA          87.166667     175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
#                                5.995652
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
# Câu 5: Cho biết giá trị trung vị (median) của các loại bia và rượu tiêu thụ ở mỗi châu lục
drinks.groupby('continent').median()
# Out:
#               id  beer_servings  spirit_servings  wine_servings  \
# continent
#             69.0          143.0            137.0           11.0
# AF          96.0           32.0              3.0            2.0
# AS         107.5           17.5             16.0            1.0
# EU          83.0          219.0            122.0          128.0
# OC         123.0           52.5             37.0            8.5
# SA          62.0          162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
#                                    6.30
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %%
# Câu 6: Cho biết số lượng rượu mạnh (spirit_servings) tiêu thụ trung bình, lớn nhất và nhỏ nhất ở mỗi châu lục 
# Gợi ý: Dùng spirit_servings.agg(['mean', 'min', 'max'])
drinks.groupby('continent').spirit_servings.agg(['mean', 'min', 'max'])
# Out:
#                  mean  min  max
# continent
#            165.739130   68  438
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302

# %%
# Câu 7: Sắp xếp dữ liệu tăng dần (sort_values) theo số lượng bia tiêu thụ
drinks_des = drinks.sort_values(by='beer_servings', ascending=True)
drinks_des
# Out:
#       id         country  beer_servings  spirit_servings  wine_servings  \
# 0      0     Afghanistan              0                0              0
# 40    40    Cook Islands              0              254             74
# 79    79            Iran              0                0              0
# 90    90          Kuwait              0                0              0
# 97    97           Libya              0                0              0
# ..   ...             ...            ...              ...            ...
# 135  135          Poland            343              215             56
# 65    65         Germany            346              117            175
# 62    62           Gabon            347               98             59
# 45    45  Czech Republic            361              170            134
# 117  117         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 40                            5.9        OC
# 79                            0.0        AS
# 90                            0.0        AS
# 97                            0.0        AF
# ..                            ...       ...
# 135                          10.9        EU
# 65                           11.3        EU
# 62                            8.9        AF
# 45                           11.8        EU
# 117                           6.8        AF
#
# [193 rows x 7 columns]

# %%
# Cho biết 5 quốc gia có lượng tiêu thụ bia lớn nhất
drinks_des.tail()
# Out:
#       id         country  beer_servings  spirit_servings  wine_servings  \
# 135  135          Poland            343              215             56
# 65    65         Germany            346              117            175
# 62    62           Gabon            347               98             59
# 45    45  Czech Republic            361              170            134
# 117  117         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 135                          10.9        EU
# 65                           11.3        EU
# 62                            8.9        AF
# 45                           11.8        EU
# 117                           6.8        AF

# %%
# Cho biết 5 quốc gia có lượng tiêu thụ bia nhỏ nhất
drinks_des.head()
# Out:
#     id       country  beer_servings  spirit_servings  wine_servings  \
# 0    0   Afghanistan              0                0              0
# 40  40  Cook Islands              0              254             74
# 79  79          Iran              0                0              0
# 90  90        Kuwait              0                0              0
# 97  97         Libya              0                0              0
#
#     total_litres_of_pure_alcohol continent
# 0                            0.0        AS
# 40                           5.9        OC
# 79                           0.0        AS
# 90                           0.0        AS
# 97                           0.0        AF

# %%
drinks_des[drinks_des['beer_servings']>0].head()
# Out:
#       id      country  beer_servings  spirit_servings  wine_servings  \
# 137  137        Qatar              1               42              7
# 38    38      Comoros              1                3              1
# 171  171  Timor-Leste              1                1              4
# 73    73        Haiti              1              326              1
# 168  168   Tajikistan              2               15              0
#
#      total_litres_of_pure_alcohol continent
# 137                           0.9        AS
# 38                            0.1        AF
# 171                           0.1        AS
# 73                            5.9
# 168                           0.3        AS

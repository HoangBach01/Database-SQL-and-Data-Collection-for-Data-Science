# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.engine import create_engine
# %load_ext sql

# %%
user = 'root'
password = 'root'
host = 'localhost:8889'
database = 'TestDB'
connection_string = "mysql+pymysql://{user}:{password}@{host}/{database}?charset=UTF8".format(user=user, password=password, host=host, database=database)
try:
    p = %sql $connection_string
    print('Database connected!')
except Exception:
    print('Unabale to connect.')
# Out:
# Database connected!

# %%
engine = create_engine(connection_string)

# %%
file_model = open('SALESDB_model.sql', 'r')
file_data = open('SALESDB_data.sql', 'r')
sql_script = sqlalchemy.text(file_model.read())
sql_insert = sqlalchemy.text(file_data.read())
# df = pd.read_sql(file_data.read(), engine)
# df
# %sql $sql_script
# %sql $sql_insert
# Out:
# fected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# ...

# %%
df = %sql select * from customers
df
# Out:
#  * mysql+pymysql://root:***@localhost:8889/TestDB?charset=UTF8
# 91 rows affected.
# [(1, 'Maria', 'Anders', 'Berlin', 'Germany', '030-0074321'),
#  (2, 'Ana', 'Trujillo', 'México D.F.', 'Mexico', '(5) 555-4729'),
#  (3, 'Antonio', 'Moreno', 'México D.F.', 'Mexico', '(5) 555-3932'),
#  (4, 'Thomas', 'Hardy', 'London', 'UK', '(171) 555-7788'),
#  (5, 'Christina', 'Berglund', 'Luleå', 'Sweden', '0921-12 34 65'),
#  (6, 'Hanna', 'Moos', 'Mannheim', 'Germany', '0621-08460'),
#  (7, 'Frédérique', 'Citeaux', 'Strasbourg', 'France', '88.60.15.31'),
#  (8, 'Martín', 'Sommer', 'Madrid', 'Spain', '(91) 555 22 82'),
#  (9, 'Laurence', 'Lebihan', 'Marseille', 'France', '91.24.45.40'),
#  (10, 'Elizabeth', 'Lincoln', 'Tsawassen', 'Canada', '(604) 555-4729'),
#  (11, 'Victoria', 'Ashworth', 'London', 'UK', '(171) 555-1212'),
#  (12, 'Patricio', 'Simpson', 'Buenos Aires', 'Argentina', '(1) 135-5555'),
#  (13, 'Francisco', 'Chang', 'México D.F.', 'Mexico', '(5) 555-3392'),
# ...

# %%
# %sql -f SALESDB_model.sql
# %sql -f SALESDB_data.sql
# Out:
# fected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# ...
